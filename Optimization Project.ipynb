# %% [markdown]
# # **JUMBO JUMJAI**
#
# An Optimization Hackathon Project

# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %% [markdown]
# ## 1. **Data Preprocessing**

# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.0.2)

# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from pulp import LpMinimize, LpProblem, LpVariable, lpSum

# %%
data = pd.read_csv('Wi-Fi.csv')
data.head()
# Out:
#        Timestamp              AP Name           Status  Total user  \
# 0  3/1/2025 0:00     AP7426.ac5b.af38  ma 662d,10h,48m           7
# 1  3/1/2025 0:00  CMU_AGR_AGRI_AP0182   up 14d,19h,24m           6
# 2  3/1/2025 0:00  CMU_AGR_AGRI_AP0183    up 70d,13h,4m           3
# 3  3/1/2025 0:00  CMU_AGR_AGRI_AP0184      up 4d,8h,9m           8
# 4  3/1/2025 0:00  CMU_AGR_AGRI_AP0185    up 48d,7h,59m           2
#
#   Availability  Bandwidth Utilization  Signal Strength (RSSI)  \
# 0       96.51%              37.454012                     -52
# 1       98.21%              95.071431                     -77
# 2       98.85%              73.199394                     -71
# 3       98.84%              59.865848                     -56
# 4       96.78%              15.601864                     -50
#
#   Packet Loss & Latency Interference Level  Device Count  Session Duration  \
# 0                   NaN           Moderate            17         27.890109
# 1                   NaN               Mild            15         30.697188
# 2                  High             Severe             7         33.415107
# 3                   NaN           Moderate            20         78.562128
# 4                   NaN               Mild             5         13.745678
#
#    Installation Cost  Maintenance Cost
# 0               4000              1000
# 1               4000              1000
# 2               4000              1000
# 3               4000              1000
# 4               4000              1000

# %%
# Split "AP Name" into components
dfsplit = data["AP Name"].str.split("_", expand=True)
dfsplit.columns = ["AP1", "AP2", "AP3", "APID"][:dfsplit.shape[1]]

# Combine "AP1", "AP2", and "AP3" into a single column
dfsplit["AP Name"] = dfsplit[["AP1", "AP2", "AP3"]].fillna('').agg('_'.join, axis=1).str.strip('_')

# Drop "AP1", "AP2", and "AP3"
dfsplit = dfsplit.drop(columns=["AP1", "AP2", "AP3"])

# Combine with the remaining columns
data = pd.concat([
    data[["Timestamp", "Status", "Total user", "Availability",
        "Bandwidth Utilization", "Signal Strength (RSSI)",
        "Packet Loss & Latency", "Interference Level", "Device Count",
        "Session Duration", "Installation Cost", "Maintenance Cost"]],
    dfsplit
], axis=1)

# Reorder columns to move 'APID' and 'AP_Combined' to the front
data = data[["APID", "AP Name"] + [col for col in data.columns if col not in ["APID", "AP Name"]]]

# %%
# Extract the last word from "AP Name" to "APID"
data['Last_Word_AP_Name'] = data['AP Name'].str.split('_').str[-1]
data['APID'] = data['Last_Word_AP_Name'] + '_' + data['APID']
data = data.drop(columns=['Last_Word_AP_Name'])

# Rename APID where None to AP0100
data.loc[data["APID"].isnull(), "APID"] = "AP0000"

# Convert Maintenance Cost to 0 where Status is up and running
data.loc[data['Status'].str.contains('up', case=False), 'Maintenance Cost'] = 0

# Split Timestamp to Date and Time
data[['Date', 'Time']] = data['Timestamp'].str.split(' ', expand=True)
data = data.drop('Timestamp', axis=1)
data['Date'] = pd.to_datetime(data['Date'])
data['Time'] = pd.to_datetime(data['Time'], errors='coerce').dt.time

# Convert 'Availability' to numeric, handling errors
data['Availability'] = pd.to_numeric(data['Availability'].str.replace('%', ''), errors='coerce')

# Update 'Total user' and 'Device Count' based on 'Status'
data.loc[data['Status'].str.contains('ma|down', case=False, na=False), ['Total user', 'Device Count']] = 0
data.head()
# Out:
# <ipython-input-34-c4ce366a547c>:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time'] = pd.to_datetime(data['Time'], errors='coerce').dt.time
#           APID           AP Name           Status  Total user  Availability  \
# 0       AP0000  AP7426.ac5b.af38  ma 662d,10h,48m           0         96.51
# 1  AGRI_AP0182      CMU_AGR_AGRI   up 14d,19h,24m           6         98.21
# 2  AGRI_AP0183      CMU_AGR_AGRI    up 70d,13h,4m           3         98.85
# 3  AGRI_AP0184      CMU_AGR_AGRI      up 4d,8h,9m           8         98.84
# 4  AGRI_AP0185      CMU_AGR_AGRI    up 48d,7h,59m           2         96.78
#
#    Bandwidth Utilization  Signal Strength (RSSI) Packet Loss & Latency  \
# 0              37.454012                     -52                   NaN
# 1              95.071431                     -77                   NaN
# 2              73.199394                     -71                  High
# 3              59.865848                     -56                   NaN
# 4              15.601864                     -50                   NaN
#
#   Interference Level  Device Count  Session Duration  Installation Cost  \
# 0           Moderate             0         27.890109               4000
# 1               Mild            15         30.697188               4000
# 2             Severe             7         33.415107               4000
# 3           Moderate            20         78.562128               4000
# 4               Mild             5         13.745678               4000
#
#    Maintenance Cost       Date      Time
# 0              1000 2025-03-01  00:00:00
# 1                 0 2025-03-01  00:00:00
# 2                 0 2025-03-01  00:00:00
# 3                 0 2025-03-01  00:00:00
# 4                 0 2025-03-01  00:00:00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172368 entries, 0 to 172367
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   APID                    172368 non-null  object
#  1   AP Name                 172368 non-null  object
#  2   Status                  172368 non-null  object
#  3   Total user              172368 non-null  int64
#  4   Availability            172368 non-null  float64
#  5   Bandwidth Utilization   172368 non-null  float64
#  6   Signal Strength (RSSI)  172368 non-null  int64
#  7   Packet Loss & Latency   129720 non-null  object
#  8   Interference Level      128736 non-null  object
#  9   Device Count            172368 non-null  int64
#  10  Session Duration        172368 non-null  float64
#  11  Installation Cost       172368 non-null  int64
#  12  Maintenance Cost        172368 non-null  int64
#  13  Date                    172368 non-null  datetime64[ns]
#  14  Time                    172368 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(6)
# memory usage: 19.7+ MB

# %% [markdown]
# **Define uninstallation costs based on Installation Cost**

# %%
uninstallation_costs = {
    3000: 450,  # For Installation Cost 3000
    4000: 600,  # For Installation Cost 4000
    5000: 750   # For Installation Cost 5000
}

# Add the 'Uninstallation Cost' column
data['Uninstallation Cost'] = data['Installation Cost'].map(uninstallation_costs)
data.head()
# Out:
#           APID           AP Name           Status  Total user  Availability  \
# 0       AP0000  AP7426.ac5b.af38  ma 662d,10h,48m           0         96.51
# 1  AGRI_AP0182      CMU_AGR_AGRI   up 14d,19h,24m           6         98.21
# 2  AGRI_AP0183      CMU_AGR_AGRI    up 70d,13h,4m           3         98.85
# 3  AGRI_AP0184      CMU_AGR_AGRI      up 4d,8h,9m           8         98.84
# 4  AGRI_AP0185      CMU_AGR_AGRI    up 48d,7h,59m           2         96.78
#
#    Bandwidth Utilization  Signal Strength (RSSI) Packet Loss & Latency  \
# 0              37.454012                     -52                   NaN
# 1              95.071431                     -77                   NaN
# 2              73.199394                     -71                  High
# 3              59.865848                     -56                   NaN
# 4              15.601864                     -50                   NaN
#
#   Interference Level  Device Count  Session Duration  Installation Cost  \
# 0           Moderate             0         27.890109               4000
# 1               Mild            15         30.697188               4000
# 2             Severe             7         33.415107               4000
# 3           Moderate            20         78.562128               4000
# 4               Mild             5         13.745678               4000
#
#    Maintenance Cost       Date      Time  Uninstallation Cost
# 0              1000 2025-03-01  00:00:00                  600
# 1                 0 2025-03-01  00:00:00                  600
# 2                 0 2025-03-01  00:00:00                  600
# 3                 0 2025-03-01  00:00:00                  600
# 4                 0 2025-03-01  00:00:00                  600

# %% [markdown]
# # 2. 24 Hours Average Data
# Convert 172368 rows (24 hrs) -> 7182 rows (24 hrs avg)

# %%
# Convert Object by using Mode
def most_frequent(series):
    return series.mode()[0] if not series.mode().empty else None

data = data.groupby(["APID", "Date"]).agg({
            "AP Name": "first",
            "Status": "first",
            "Total user": "mean",
            "Availability": "mean",
            "Bandwidth Utilization": "mean",
            "Signal Strength (RSSI)": "mean",
            "Packet Loss & Latency": most_frequent,
            "Interference Level": most_frequent,
            "Device Count": "mean",
            "Session Duration": "mean",
            "Installation Cost": "first",
            "Maintenance Cost": "first"
        }).reset_index()

data.head()
# Out:
#           APID       Date       AP Name           Status  Total user  \
# 0  40YD_AP8359 2025-03-01  CMU_ENG_40YD    up 84d,8h,44m    5.083333
# 1  40YD_AP8360 2025-03-01  CMU_ENG_40YD   up 11d,19h,34m    2.250000
# 2  40YD_AP8361 2025-03-01  CMU_ENG_40YD   up 50d,19h,34m    3.791667
# 3  40YD_AP8533 2025-03-01  TOT_ENG_40YD    up 84d,8h,54m    3.250000
# 4  40YD_AP8534 2025-03-01  TOT_ENG_40YD  ma 147d,14h,45m    0.000000
#
#    Availability  Bandwidth Utilization  Signal Strength (RSSI)  \
# 0     99.698750              48.332658              -55.458333
# 1     99.172083              19.929650              -70.916667
# 2     99.788750              61.890893              -34.291667
# 3     97.605000              96.926939              -75.416667
# 4     99.772083              83.879881              -34.833333
#
#   Packet Loss & Latency Interference Level  Device Count  Session Duration  \
# 0                  None               Mild      9.875000        110.198275
# 1                  High               None      4.083333         29.023893
# 2                  High             Severe      6.250000         49.187809
# 3                  High           Moderate      5.708333        101.641828
# 4                  None             Severe      0.000000         27.252927
#
#    Installation Cost  Maintenance Cost
# 0               4000                 0
# 1               4000                 0
# 2               4000                 0
# 3               4000                 0
# 4               4000              1000

# %% [markdown]
# Rounding Total Average User to Integer

# %%
data = data.rename(columns={"Total user": "Total Average User"})
data["Total Average User"] = data["Total Average User"].round(0).astype(int)
data.head()
# Out:
#           APID       Date       AP Name           Status  Total Average User  \
# 0  40YD_AP8359 2025-03-01  CMU_ENG_40YD    up 84d,8h,44m                   5
# 1  40YD_AP8360 2025-03-01  CMU_ENG_40YD   up 11d,19h,34m                   2
# 2  40YD_AP8361 2025-03-01  CMU_ENG_40YD   up 50d,19h,34m                   4
# 3  40YD_AP8533 2025-03-01  TOT_ENG_40YD    up 84d,8h,54m                   3
# 4  40YD_AP8534 2025-03-01  TOT_ENG_40YD  ma 147d,14h,45m                   0
#
#    Availability  Bandwidth Utilization  Signal Strength (RSSI)  \
# 0     99.698750              48.332658              -55.458333
# 1     99.172083              19.929650              -70.916667
# 2     99.788750              61.890893              -34.291667
# 3     97.605000              96.926939              -75.416667
# 4     99.772083              83.879881              -34.833333
#
#   Packet Loss & Latency Interference Level  Device Count  Session Duration  \
# 0                  None               Mild      9.875000        110.198275
# 1                  High               None      4.083333         29.023893
# 2                  High             Severe      6.250000         49.187809
# 3                  High           Moderate      5.708333        101.641828
# 4                  None             Severe      0.000000         27.252927
#
#    Installation Cost  Maintenance Cost
# 0               4000                 0
# 1               4000                 0
# 2               4000                 0
# 3               4000                 0
# 4               4000              1000

# %% [markdown]
# # 3. Assign Location Name to Each APID

# %%
print("Total Unique APID =", data["APID"].nunique())
print("Total Unique AP Name =", data['AP Name'].nunique())
# Out:
# Total Unique APID = 7181
# Total Unique AP Name = 166

# %% [markdown]
# Take a look at the Location.csv

# %%
location = pd.read_csv('/content/สถานที่.csv')
location.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-040e365052a7> in <cell line: 0>()
# ----> 1 location = pd.read_csv('/content/สถานที่.csv')
#       2 location.tail()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/สถานที่.csv'

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AP2_AP3    148 non-null    object
#  1   Location1  148 non-null    object
#  2   Location2  6 non-null      object
#  3   Location3  4 non-null      object
#  4   Location4  2 non-null      object
#  5   Location5  1 non-null      object
#  6   Location6  1 non-null      object
#  7   Location7  1 non-null      object
# dtypes: object(8)
# memory usage: 9.4+ KB

# %%
location['AP2_AP3'].unique()
# Out:
# array(['AGR_AGRI', 'AGR_ARTMU', 'AGR_ASSET', 'AGR_BA', 'AGR_BUS',
#        'AGR_CLEANWT', 'AGR_CULT', 'AGR_EDU', 'AGR_FIN', 'AGR_GRAD',
#        'AGR_LI', 'AGR_OD', 'AGR_OOP', 'AGR_PTRI', 'AGR_RIHES', 'AGR_SRI',
#        'AGR_STRI', 'AGR_VET', 'COM_AKD', 'COM_ASSET', 'COM_CAMT',
#        'COM_CELEBRATE', 'COM_CMUHEART', 'COM_CNOC', 'COM_COFFAK',
#        'COM_COOP', 'COM_ECON', 'COM_FCMU', 'COM_HISTORY', 'COM_HM',
#        'COM_ITSC', 'COM_ITSCC', 'COM_LAW', 'COM_LIBR', 'COM_MASS',
#        'COM_OD', 'COM_OOP', 'COM_POL', 'COM_POST', 'COM_REG', 'COM_SAVE',
#        'COM_SCB', 'COM_SCI', 'COM_SLAK', 'COM_SLDM', 'COM_SOC',
#        'COM_SOCF', 'COM_SPP', 'COM_SWC', 'COM_VCMU', 'ENG_40YD',
#        'ENG_AMS', 'ENG_ARC', 'ENG_ARCHER', 'ENG_CAMT', 'ENG_CONTAINER',
#        'ENG_DMST', 'ENG_ENG', 'ENG_FAI', 'ENG_FLAT1', 'ENG_FLAT2',
#        'ENG_FLAT3', 'ENG_FLAT4', 'ENG_FLAT7', 'ENG_FLAT8', 'ENG_FOODCEN',
#        'ENG_GENT3', 'ENG_GENT4', 'ENG_GENT5', 'ENG_GENT6', 'ENG_GENT7',
#        'ENG_GH', 'ENG_GYM', 'ENG_LADY2', 'ENG_LADY3', 'ENG_LADY4',
#        'ENG_LADY5', 'ENG_LADY6', 'ENG_LADY7', 'ENG_OD', 'ENG_OOP',
#        'ENG_PEA', 'ENG_PINKD', 'ENG_PLHC', 'ENG_PUBH', 'ENG_PUBHEALTH',
#        'ENG_SMO', 'ENG_STADIUM', 'ENG_SWIM', 'ENG_TENNIS', 'ENG_TLIC',
#        'ENG_WAT', 'LPN_DORM1', 'LPN_DORM2', 'LPN_HPB4', 'LPN_HPB5',
#        'LPN_OFFICE', 'MAE_AGRI', 'MAE_AGRO', 'MAE_ERDI', 'MAE_FIPC',
#        'MAE_LAC', 'MAE_MHD', 'MAE_OD', 'MAE_OOP', 'MAE_RICE', 'MAE_STEP',
#        'MAE_VET', 'MED_ALUMNI', 'MED_AMS', 'MED_AMSDORM', 'MED_DENT',
#        'MED_DENTDORM', 'MED_FLAT56', 'MED_GHALL', 'MED_IC', 'MED_MED',
#        'MED_MEDDORM14F', 'MED_MEDDORM4', 'MED_MEDDORM7FL',
#        'MED_MEDDORMF437', 'MED_MEDFLAT76', 'MED_MEDFLAT86',
#        'MED_MEDSDORMF2', 'MED_MEDSDORMM1', 'MED_MEDSDORMM2',
#        'MED_MEDSDORMM3', 'MED_NUR', 'MED_NURD2', 'MED_NURD5', 'MED_NURD9',
#        'MED_OD', 'MED_OOP', 'MED_PHAR', 'MED_PHARDORM', 'MED_RIHES',
#        'MED_SDD', 'MED_SDP', 'MED_UNIS', 'AGR_SCMC', 'ENG_FLAT5',
#        'ENG_FLAT6', 'ENG_GENT1', 'ENG_GENT2', 'ENG_LADY11', 'ENG_LADY12',
#        'ENG_RIMKLONG', 'ENG_SCMC'], dtype=object)

# %%
# Remove "CMU_" or "TOT_" from "AP Name"
data["AP Name"] = data["AP Name"].str.replace("CMU_", "", regex=False)
data["AP Name"] = data["AP Name"].str.replace("TOT_", "", regex=False)
print("Total Unique Location =", location['AP2_AP3'].nunique())
print("Total Unique AP Name =", data['AP Name'].nunique())
# Out:
# Total Unique Location = 148
# Total Unique AP Name = 149

# %%
ap_names_data = set(data["AP Name"].unique())
ap_names_location = set(location["AP2_AP3"].unique())

# Find elements in data but not in location
diff1 = ap_names_data - ap_names_location
print("AP Names in 'data' but not in 'location':", diff1)

# Find elements in location but not in data
diff2 = ap_names_location - ap_names_data
print("AP Names in 'location' but not in 'data':", diff2)
# Out:
# AP Names in 'data' but not in 'location': {'AP7426.ac5b.af38'}
# AP Names in 'location' but not in 'data': set()

# %% [markdown]
# **Merge the data and location DataFrames based on "AP Name" and "AP2_AP3"**

# %%
data = pd.merge(data, location, left_on='AP Name', right_on='AP2_AP3', how='left')
data = data.drop(columns=['AP2_AP3'])
data.head()
# Out:
#           APID       Date   AP Name           Status  Total Average User  \
# 0  40YD_AP8359 2025-03-01  ENG_40YD    up 84d,8h,44m                   5
# 1  40YD_AP8360 2025-03-01  ENG_40YD   up 11d,19h,34m                   2
# 2  40YD_AP8361 2025-03-01  ENG_40YD   up 50d,19h,34m                   4
# 3  40YD_AP8533 2025-03-01  ENG_40YD    up 84d,8h,54m                   3
# 4  40YD_AP8534 2025-03-01  ENG_40YD  ma 147d,14h,45m                   0
#
#    Availability  Bandwidth Utilization  Signal Strength (RSSI)  \
# 0     99.698750              48.332658              -55.458333
# 1     99.172083              19.929650              -70.916667
# 2     99.788750              61.890893              -34.291667
# 3     97.605000              96.926939              -75.416667
# 4     99.772083              83.879881              -34.833333
#
#   Packet Loss & Latency Interference Level  ...  Session Duration  \
# 0                  None               Mild  ...        110.198275
# 1                  High               None  ...         29.023893
# 2                  High             Severe  ...         49.187809
# 3                  High           Moderate  ...        101.641828
# 4                  None             Severe  ...         27.252927
#
#    Installation Cost  Maintenance Cost   Location1 Location2 Location3  \
# 0               4000                 0  หอสี่สิบปี       NaN       NaN
# 1               4000                 0  หอสี่สิบปี       NaN       NaN
# 2               4000                 0  หอสี่สิบปี       NaN       NaN
# 3               4000                 0  หอสี่สิบปี       NaN       NaN
# 4               4000              1000  หอสี่สิบปี       NaN       NaN
#
#   Location4 Location5 Location6 Location7
# 0       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#             APID       Date  AP Name          Status  Total Average User  \
# 7176  VET_AP7823 2025-03-01  MAE_VET   up 1d,15h,54m                   8
# 7177  VET_AP7824 2025-03-01  MAE_VET  ma 86d,10h,44m                   0
# 7178  VET_AP7825 2025-03-01  MAE_VET   up 1d,15h,54m                   3
# 7179  WAT_AP6409 2025-03-01  ENG_WAT  up 28d,11h,24m                   4
# 7180  WAT_AP6667 2025-03-01  ENG_WAT   up 4d,19h,34m                   2
#
#       Availability  Bandwidth Utilization  Signal Strength (RSSI)  \
# 7176     95.212083              34.714214              -42.666667
# 7177     92.808333              72.860357              -73.375000
# 7178     95.166667              65.684364              -32.750000
# 7179     99.258333              46.164563              -45.833333
# 7180     98.793750               7.461262              -48.666667
#
#      Packet Loss & Latency Interference Level  ...  Session Duration  \
# 7176                   Low               None  ...         22.247423
# 7177                  High           Moderate  ...        101.999980
# 7178                   Low               Mild  ...         33.601841
# 7179                Medium               None  ...         51.556984
# 7180                Medium               Mild  ...         97.792896
#
#       Installation Cost  Maintenance Cost                        Location1  \
# 7176               4000                 0  แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง
# 7177               4000              1000  แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง
# 7178               4000                 0  แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง
# 7179               4000                 0                        วัดฝายหิน
# 7180               4000                 0                        วัดฝายหิน
#
#      Location2 Location3 Location4 Location5 Location6 Location7
# 7176       NaN       NaN       NaN       NaN       NaN       NaN
# 7177       NaN       NaN       NaN       NaN       NaN       NaN
# 7178       NaN       NaN       NaN       NaN       NaN       NaN
# 7179       NaN       NaN       NaN       NaN       NaN       NaN
# 7180       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# **Save the DataFrame to a CSV file**

# %%
data.to_csv('processed_wifi_data.csv', index=False)

# Download the file (optional, but useful in Colab)
from google.colab import files
files.download('processed_wifi_data.csv')

# %% [markdown]
# # 4. **Optimization Model**
# **Decision Variable:** Let
# 𝑥
# 𝑖
# x
# i
# ​
#   be a binary variable (1 = install/keep AP, 0 = remove AP) for each AP.
#
# **Objective:** MIN COST
#
# **Constraints:**

# %%
df = data

# %%
from pulp import LpProblem, LpMinimize, LpVariable, lpSum
df = data
# กำหนดโมเดลลดต้นทุน
model = LpProblem("WiFi_Cost_Optimization", LpMinimize)

# จำนวน AP ที่มีอยู่
num_ap = len(df)

# กำหนดประเภท AP
ap_types = {
    0: {"install_cost": 3000, "maintenance_cost": 500, "capacity": 50},
    1: {"install_cost": 4000, "maintenance_cost": 1000, "capacity": 70},
    2: {"install_cost": 5000, "maintenance_cost": 1500, "capacity": 100}
}

# กำหนดประเภท AP จาก maintenance_cost
def classify_ap_type(cost):
    for key, value in ap_types.items():
        if cost == value["maintenance_cost"]:
            return key
    return -1

df["ap_type"] = df["Maintenance Cost"].apply(classify_ap_type)
df = df[df["ap_type"] != -1]  # กรองเฉพาะ AP ที่มีข้อมูล

# กำหนด capacity ตามประเภท AP
df["capacity"] = df["ap_type"].apply(lambda x: ap_types[x]["capacity"])

# ตัวแปรตัดสินใจ (0 = ไม่ซ่อม, 1 = ซ่อม)
repair = {i: LpVariable(f"repair_{i}", cat="Binary") for i in df.index}
replace = {i: LpVariable(f"replace_{i}", cat="Binary") for i in df.index}

# ฟังก์ชันเป้าหมาย (Objective Function) → ลดค่าใช้จ่ายรวม
model += lpSum(
    df.loc[i, "Maintenance Cost"] * repair[i] + df.loc[i, "Installation Cost"] * replace[i]
    for i in df.index
)
# ข้อจำกัด (Constraints)

# 1. รองรับผู้ใช้ทั้งหมด ≥ 38,000 คน
model += lpSum(df.loc[i, "capacity"] * (repair[i] + replace[i]) for i in df.index) >= 38000

# 2. ไม่สามารถซ่อมและซื้อใหม่พร้อมกันได้
for i in df.index:
    model += repair[i] + replace[i] <= 1

# 3. จำกัดงบประมาณรวม ไม่เกิน MAX_BUDGET
MAX_BUDGET = 40000000
model += lpSum(
    df.loc[i, "Maintenance Cost"] * repair[i] + df.loc[i, "Installation Cost"] * replace[i]
    for i in df.index
) <= MAX_BUDGET

# 4. บังคับให้ APs ที่สถานะเป็น 'ma' ต้องถูกซ่อมหรือเปลี่ยน
for i in df[df["Status"] == "ma"].index:
    model += repair[i] + replace[i] == 1

# 5. ต้องรักษาคุณภาพสัญญาณเครือข่าย (RSSI ≥ -65 dBm)
model += lpSum(repair[i] * df.loc[i, "Signal Strength (RSSI)"] for i in df.index) >= -65 * lpSum(repair[i] for i in df.index)

# 6. จำกัดค่าใช้จ่ายในแต่ละ Location ไม่ให้สูงเกินไป
MAX_COST_PER_LOC = 270000
for loc in df["Location1"].unique():
    model += lpSum(
        (df.loc[i, "Maintenance Cost"] * repair[i] + df.loc[i, "Installation Cost"] * replace[i])
        for i in df[df["Location1"] == loc].index
    ) <= MAX_COST_PER_LOC

# แก้ปัญหา
model.solve()

# แสดงผลลัพธ์ในรูปแบบที่อ่านง่าย
print("Results of AP Repair and Replacement:")
for i in df.index:
    if repair[i].varValue == 1:
        print(f"Repair AP {df.loc[i, 'APID']} (Repair needed)")
    if replace[i].varValue == 1:
        print(f"Replace AP {df.loc[i, 'APID']} (Replacement needed)")

# # แสดงผลลัพธ์
# for i in df.index:
#     if repair[i].varValue == 1:
#         print(f"Repair AP {df.loc[i, 'APID']}")
#     if replace[i].varValue == 1:
#         print(f"Replace AP {df.loc[i, 'APID']}")
# Out:
# <ipython-input-19-9739138538ff>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["capacity"] = df["ap_type"].apply(lambda x: ap_types[x]["capacity"])
# Results of AP Repair and Replacement:
# Repair AP 40YD_AP8534 (Repair needed)
# Repair AP 40YD_AP8535 (Repair needed)
# Repair AP 40YD_AP8536 (Repair needed)
# Repair AP 40YD_AP8537 (Repair needed)
# Repair AP 40YD_AP8538 (Repair needed)
# Repair AP 40YD_AP8539 (Repair needed)
# Repair AP 40YD_AP8540 (Repair needed)
# Repair AP 40YD_AP8541 (Repair needed)
# Repair AP 40YD_AP8542 (Repair needed)
# Repair AP 40YD_AP8543 (Repair needed)
# Repair AP 40YD_AP8544 (Repair needed)
# Repair AP 40YD_AP8545 (Repair needed)
# Repair AP 40YD_AP8546 (Repair needed)
# Repair AP 40YD_AP8547 (Repair needed)
# Repair AP 40YD_AP8548 (Repair needed)
# Repair AP 40YD_AP8549 (Repair needed)
# Repair AP 40YD_AP8550 (Repair needed)
# Repair AP 40YD_AP8551 (Repair needed)
# Repair AP 40YD_AP8552 (Repair needed)
# Repair AP 40YD_AP8553 (Repair needed)
# Repair AP 40YD_AP8554 (Repair needed)
# Repair AP 40YD_AP8555 (Repair needed)
# Repair AP 40YD_AP8556 (Repair needed)
# Repair AP 40YD_AP8557 (Repair needed)
# Repair AP 40YD_AP8559 (Repair needed)
# Repair AP 40YD_AP8560 (Repair needed)
# Repair AP 40YD_AP8561 (Repair needed)
# Repair AP 40YD_AP8562 (Repair needed)
# Repair AP 40YD_AP8563 (Repair needed)
# Repair AP 40YD_AP8564 (Repair needed)
# Repair AP 40YD_AP8565 (Repair needed)
# Repair AP 40YD_AP8566 (Repair needed)
# Repair AP 40YD_AP8567 (Repair needed)
# Repair AP 40YD_AP8568 (Repair needed)
# Repair AP 40YD_AP8569 (Repair needed)
# Repair AP 40YD_AP8570 (Repair needed)
# Repair AP 40YD_AP8571 (Repair needed)
# Repair AP 40YD_AP8572 (Repair needed)
# Repair AP 40YD_AP8573 (Repair needed)
# Repair AP 40YD_AP8574 (Repair needed)
# Repair AP 40YD_AP8575 (Repair needed)
# Repair AP 40YD_AP8576 (Repair needed)
# Repair AP 40YD_AP8577 (Repair needed)
# Repair AP 40YD_AP8578 (Repair needed)
# Repair AP 40YD_AP8579 (Repair needed)
# Repair AP 40YD_AP8580 (Repair needed)
# Repair AP 40YD_AP8581 (Repair needed)
# Repair AP 40YD_AP8582 (Repair needed)
# Repair AP 40YD_AP8637 (Repair needed)
# Repair AP 40YD_AP8638 (Repair needed)
# Repair AP 40YD_AP8639 (Repair needed)
# Repair AP 40YD_AP8640 (Repair needed)
# Repair AP 40YD_AP8641 (Repair needed)
# Repair AP 40YD_AP8642 (Repair needed)
# Repair AP 40YD_AP8643 (Repair needed)
# Repair AP 40YD_AP8644 (Repair needed)
# Repair AP 40YD_AP8646 (Repair needed)
# Repair AP 40YD_AP8647 (Repair needed)
# Repair AP 40YD_AP8648 (Repair needed)
# Repair AP 40YD_AP8649 (Repair needed)
# Repair AP 40YD_AP8650 (Repair needed)
# Repair AP 40YD_AP8651 (Repair needed)
# Repair AP 40YD_AP8652 (Repair needed)
# Repair AP 40YD_AP8653 (Repair needed)
# Repair AP 40YD_AP8654 (Repair needed)
# Repair AP 40YD_AP8655 (Repair needed)
# Repair AP 40YD_AP8656 (Repair needed)
# Repair AP 40YD_AP8657 (Repair needed)
# Repair AP 40YD_AP8658 (Repair needed)
# Repair AP 40YD_AP8659 (Repair needed)
# Repair AP 40YD_AP8661 (Repair needed)
# Repair AP 40YD_AP8662 (Repair needed)
# Repair AP 40YD_AP8663 (Repair needed)
# Repair AP 40YD_AP8664 (Repair needed)
# Repair AP 40YD_AP8665 (Repair needed)
# Repair AP 40YD_AP8666 (Repair needed)
# Repair AP 40YD_AP8667 (Repair needed)
# Repair AP 40YD_AP8668 (Repair needed)
# Repair AP 40YD_AP8669 (Repair needed)
# Repair AP 40YD_AP8670 (Repair needed)
# Repair AP 40YD_AP8671 (Repair needed)
# Repair AP 40YD_AP8672 (Repair needed)
# Repair AP 40YD_AP8673 (Repair needed)
# Repair AP 40YD_AP8674 (Repair needed)
# Repair AP 40YD_AP8676 (Repair needed)
# Repair AP 40YD_AP8677 (Repair needed)
# Repair AP 40YD_AP8678 (Repair needed)
# Repair AP 40YD_AP8679 (Repair needed)
# Repair AP 40YD_AP8680 (Repair needed)
# Repair AP 40YD_AP8681 (Repair needed)
# Repair AP 40YD_AP8682 (Repair needed)
# Repair AP 40YD_AP8683 (Repair needed)
# Repair AP 40YD_AP8684 (Repair needed)
# Repair AP 40YD_AP8685 (Repair needed)
# Repair AP 40YD_AP8686 (Repair needed)
# Repair AP 40YD_AP8687 (Repair needed)
# Repair AP 40YD_AP8688 (Repair needed)
# Repair AP 40YD_AP8689 (Repair needed)
# Repair AP 40YD_AP8691 (Repair needed)
# Repair AP 40YD_AP8692 (Repair needed)
# Repair AP 40YD_AP8693 (Repair needed)
# Repair AP 40YD_AP8694 (Repair needed)
# Repair AP 40YD_AP8695 (Repair needed)
# Repair AP 40YD_AP8696 (Repair needed)
# Repair AP 40YD_AP8697 (Repair needed)
# Repair AP 40YD_AP8698 (Repair needed)
# Repair AP 40YD_AP8699 (Repair needed)
# Repair AP 40YD_AP8700 (Repair needed)
# Repair AP 40YD_AP8701 (Repair needed)
# Repair AP 40YD_AP8702 (Repair needed)
# Repair AP 40YD_AP8703 (Repair needed)
# Repair AP 40YD_AP8704 (Repair needed)
# Repair AP 40YD_AP8706 (Repair needed)
# Repair AP 40YD_AP8707 (Repair needed)
# Repair AP 40YD_AP8708 (Repair needed)
# Repair AP 40YD_AP8709 (Repair needed)
# Repair AP 40YD_AP8710 (Repair needed)
# Repair AP 40YD_AP8711 (Repair needed)
# Repair AP 40YD_AP8712 (Repair needed)
# Repair AP 40YD_AP8713 (Repair needed)
# Repair AP 40YD_AP8714 (Repair needed)
# Repair AP 40YD_AP8715 (Repair needed)
# Repair AP 40YD_AP8716 (Repair needed)
# Repair AP 40YD_AP8717 (Repair needed)
# Repair AP 40YD_AP8718 (Repair needed)
# Repair AP 40YD_AP8719 (Repair needed)
# Repair AP 40YD_AP8721 (Repair needed)
# Repair AP 40YD_AP8722 (Repair needed)
# Repair AP 40YD_AP8723 (Repair needed)
# Repair AP 40YD_AP8724 (Repair needed)
# Repair AP 40YD_AP8725 (Repair needed)
# Repair AP 40YD_AP8726 (Repair needed)
# Repair AP 40YD_AP8727 (Repair needed)
# Repair AP 40YD_AP8728 (Repair needed)
# Repair AP 40YD_AP8729 (Repair needed)
# Repair AP 40YD_AP8730 (Repair needed)
# Repair AP 40YD_AP8731 (Repair needed)
# Repair AP 40YD_AP8732 (Repair needed)
# Repair AP 40YD_AP8733 (Repair needed)
# Repair AP 40YD_AP8734 (Repair needed)
# Repair AP 40YD_AP8736 (Repair needed)
# Repair AP 40YD_AP8737 (Repair needed)
# Repair AP 40YD_AP8738 (Repair needed)
# Repair AP 40YD_AP8739 (Repair needed)
# Repair AP 40YD_AP8740 (Repair needed)
# Repair AP 40YD_AP8741 (Repair needed)
# Repair AP 40YD_AP8742 (Repair needed)
# Repair AP 40YD_AP8743 (Repair needed)
# Repair AP 40YD_AP8744 (Repair needed)
# Repair AP 40YD_AP8745 (Repair needed)
# Repair AP 40YD_AP8746 (Repair needed)
# Repair AP 40YD_AP8747 (Repair needed)
# Repair AP 40YD_AP8748 (Repair needed)
# Repair AP 40YD_AP8749 (Repair needed)
# Repair AP 40YD_AP8752 (Repair needed)
# Repair AP 40YD_AP8753 (Repair needed)
# Repair AP 40YD_AP8754 (Repair needed)
# Repair AP 40YD_AP8755 (Repair needed)
# Repair AP 40YD_AP8756 (Repair needed)
# Repair AP 40YD_AP8757 (Repair needed)
# Repair AP 40YD_AP8758 (Repair needed)
# Repair AP 40YD_AP8759 (Repair needed)
# Repair AP 40YD_AP8760 (Repair needed)
# Repair AP 40YD_AP8761 (Repair needed)
# Repair AP 40YD_AP8762 (Repair needed)
# Repair AP 40YD_AP8763 (Repair needed)
# Repair AP 40YD_AP8764 (Repair needed)
# Repair AP 40YD_AP8765 (Repair needed)
# Repair AP 40YD_AP8767 (Repair needed)
# Repair AP 40YD_AP8768 (Repair needed)
# Repair AP 40YD_AP8769 (Repair needed)
# Repair AP 40YD_AP8770 (Repair needed)
# Repair AP 40YD_AP8771 (Repair needed)
# Repair AP 40YD_AP8772 (Repair needed)
# Repair AP 40YD_AP8773 (Repair needed)
# Repair AP 40YD_AP8774 (Repair needed)
# Repair AP 40YD_AP8775 (Repair needed)
# Repair AP 40YD_AP8776 (Repair needed)
# Repair AP 40YD_AP8777 (Repair needed)
# Repair AP 40YD_AP8778 (Repair needed)
# Repair AP 40YD_AP8779 (Repair needed)
# Repair AP 40YD_AP8780 (Repair needed)
# Repair AP 40YD_AP8782 (Repair needed)
# Repair AP 40YD_AP8783 (Repair needed)
# Repair AP 40YD_AP8784 (Repair needed)
# Repair AP 40YD_AP8785 (Repair needed)
# Repair AP 40YD_AP8786 (Repair needed)
# Repair AP 40YD_AP8787 (Repair needed)
# Repair AP 40YD_AP8788 (Repair needed)
# Repair AP 40YD_AP8789 (Repair needed)
# Repair AP 40YD_AP8790 (Repair needed)
# Repair AP 40YD_AP8791 (Repair needed)
# Repair AP 40YD_AP8792 (Repair needed)
# Repair AP 40YD_AP8793 (Repair needed)
# Repair AP 40YD_AP8794 (Repair needed)
# Repair AP 40YD_AP8795 (Repair needed)
# Repair AP AGRI_AP1100 (Repair needed)
# Repair AP AGRI_AP8089 (Repair needed)
# Repair AP AGRI_AP8096 (Repair needed)
# Repair AP AGRI_AP8098 (Repair needed)
# Repair AP AGRO_AP0308 (Repair needed)
# Repair AP AGRO_AP5553 (Repair needed)
# Repair AP AP0000 (Repair needed)
# Repair AP ARCHER_AP6134 (Repair needed)
# Repair AP CAMT_AP0060 (Repair needed)
# Repair AP CAMT_AP0659 (Repair needed)
# Repair AP CAMT_AP0662 (Repair needed)
# Repair AP CAMT_AP0674 (Repair needed)
# Repair AP CAMT_AP8247 (Repair needed)
# Repair AP CAMT_AP8250 (Repair needed)
# Repair AP CAMT_AP8251 (Repair needed)
# Repair AP CAMT_AP8252 (Repair needed)
# Repair AP CAMT_AP8255 (Repair needed)
# Repair AP CAMT_AP8257 (Repair needed)
# Repair AP CAMT_AP8262 (Repair needed)
# Repair AP CELEBRATE_AP6386 (Repair needed)
# Repair AP CMUHEART_AP6384 (Repair needed)
# Repair AP CNOC_AP5710 (Repair needed)
# Repair AP COFFAK_AP6405 (Repair needed)
# Repair AP CONTAINER_AP6408 (Repair needed)
# Repair AP DENTDORM_AP1763 (Repair needed)
# Repair AP DENTDORM_AP4308 (Repair needed)
# Repair AP DENTDORM_AP4310 (Repair needed)
# Repair AP DENT_AP0248 (Repair needed)
# Repair AP EDU_AP4721 (Repair needed)
# Repair AP EDU_AP4725 (Repair needed)
# Repair AP EDU_AP8013 (Repair needed)
# Repair AP EDU_AP8014 (Repair needed)
# Repair AP EDU_AP8015 (Repair needed)
# Repair AP ENG_AP0856 (Repair needed)
# Repair AP ENG_AP0869 (Repair needed)
# Repair AP ENG_AP4464 (Repair needed)
# Repair AP ENG_AP4465 (Repair needed)
# Repair AP ENG_AP4612 (Repair needed)
# Repair AP ENG_AP4676 (Repair needed)
# Repair AP ENG_AP4679 (Repair needed)
# Repair AP ENG_AP4680 (Repair needed)
# Repair AP ENG_AP4699 (Repair needed)
# Repair AP ENG_AP6677 (Repair needed)
# Repair AP ERDI_AP2077 (Repair needed)
# Repair AP FLAT6_AP8636 (Repair needed)
# Repair AP GRAD_AP1156 (Repair needed)
# Repair AP GRAD_AP1159 (Repair needed)
# Repair AP GRAD_AP1164 (Repair needed)
# Repair AP GRAD_AP1165 (Repair needed)
# Repair AP GRAD_AP5293 (Repair needed)
# Repair AP GRAD_AP5297 (Repair needed)
# Repair AP GRAD_AP5298 (Repair needed)
# Repair AP GRAD_AP5299 (Repair needed)
# Repair AP HM_AP4831 (Repair needed)
# Repair AP HPB4_AP7627 (Repair needed)
# Repair AP HPB4_AP7630 (Repair needed)
# Repair AP ITSC_AP5687 (Repair needed)
# Repair AP ITSC_AP5703 (Repair needed)
# Repair AP ITSC_AP5705 (Repair needed)
# Repair AP ITSC_AP5706 (Repair needed)
# Repair AP ITSC_AP5707 (Repair needed)
# Repair AP ITSC_AP5708 (Repair needed)
# Repair AP ITSC_AP6229 (Repair needed)
# Repair AP LIBR_AP6690 (Repair needed)
# Repair AP LIBR_AP6691 (Repair needed)
# Repair AP LI_AP5309 (Repair needed)
# Repair AP MEDSDORMM2_AP0240 (Repair needed)
# Repair AP MEDSDORMM2_AP1579 (Repair needed)
# Repair AP MEDSDORMM2_AP1588 (Repair needed)
# Repair AP MEDSDORMM2_AP3958 (Repair needed)
# Repair AP MED_AP1198 (Repair needed)
# Repair AP MED_AP1224 (Repair needed)
# Repair AP MED_AP1628 (Repair needed)
# Repair AP MED_AP3185 (Repair needed)
# Repair AP MED_AP3204 (Repair needed)
# Repair AP MED_AP3220 (Repair needed)
# Repair AP MED_AP3221 (Repair needed)
# Repair AP MED_AP3222 (Repair needed)
# Repair AP MED_AP3223 (Repair needed)
# Repair AP MED_AP3224 (Repair needed)
# Repair AP MED_AP3225 (Repair needed)
# Repair AP MED_AP3226 (Repair needed)
# Repair AP MED_AP3228 (Repair needed)
# Repair AP MED_AP3229 (Repair needed)
# Repair AP MED_AP3231 (Repair needed)
# Repair AP MED_AP3233 (Repair needed)
# Repair AP MED_AP3351 (Repair needed)
# Repair AP MED_AP3352 (Repair needed)
# Repair AP MED_AP3353 (Repair needed)
# Repair AP MED_AP3354 (Repair needed)
# Repair AP MED_AP3355 (Repair needed)
# Repair AP MED_AP3360 (Repair needed)
# Repair AP MED_AP3361 (Repair needed)
# Repair AP MED_AP3376 (Repair needed)
# Repair AP MED_AP3384 (Repair needed)
# Repair AP MED_AP3385 (Repair needed)
# Repair AP MED_AP3477 (Repair needed)
# Repair AP MED_AP3700 (Repair needed)
# Repair AP MED_AP3812 (Repair needed)
# Repair AP MED_AP6126 (Repair needed)
# Repair AP MED_AP6582 (Repair needed)
# Repair AP MED_AP6771 (Repair needed)
# Repair AP MED_AP6772 (Repair needed)
# Repair AP MHD_AP22095 (Repair needed)
# Repair AP MHD_AP6318 (Repair needed)
# Repair AP MHD_AP6319 (Repair needed)
# Repair AP NURD9_AP1661 (Repair needed)
# Repair AP OD_AP1010 (Repair needed)
# Repair AP OD_AP1011 (Repair needed)
# Repair AP OD_AP1020 (Repair needed)
# Repair AP OD_AP1027 (Repair needed)
# Repair AP OFFICE_AP7625 (Repair needed)
# Repair AP OOP_AP6275 (Repair needed)
# Repair AP REG_AP5813 (Repair needed)
# Repair AP RIHES_AP1175 (Repair needed)
# Repair AP RIHES_AP1976 (Repair needed)
# Repair AP RIHES_AP1977 (Repair needed)
# Repair AP RIHES_AP5727 (Repair needed)
# Repair AP RIHES_AP5729 (Repair needed)
# Repair AP RIHES_AP5731 (Repair needed)
# Repair AP SCI_AP0535 (Repair needed)
# Repair AP SCI_AP0588 (Repair needed)
# Repair AP SCI_AP0589 (Repair needed)
# Repair AP SCI_AP5140 (Repair needed)
# Repair AP SDD_AP7901 (Repair needed)
# Repair AP SDD_AP7902 (Repair needed)
# Repair AP SDD_AP7907 (Repair needed)
# Repair AP SDD_AP7908 (Repair needed)
# Repair AP SDD_AP7909 (Repair needed)
# Repair AP SDD_AP7910 (Repair needed)
# Repair AP SDD_AP7912 (Repair needed)
# Repair AP SDD_AP7913 (Repair needed)
# Repair AP SDD_AP7914 (Repair needed)
# Repair AP SDD_AP7915 (Repair needed)
# Repair AP SDD_AP7917 (Repair needed)
# Repair AP SDD_AP7918 (Repair needed)
# Repair AP SDD_AP7919 (Repair needed)
# Repair AP SDD_AP7920 (Repair needed)
# Repair AP SDD_AP7921 (Repair needed)
# Repair AP SDD_AP7922 (Repair needed)
# Repair AP SDD_AP7923 (Repair needed)
# Repair AP SDD_AP7924 (Repair needed)
# Repair AP SDD_AP7926 (Repair needed)
# Repair AP SDD_AP7927 (Repair needed)
# Repair AP SDD_AP7928 (Repair needed)
# Repair AP SDD_AP7930 (Repair needed)
# Repair AP SDD_AP7931 (Repair needed)
# Repair AP SDD_AP7932 (Repair needed)
# Repair AP SDD_AP7935 (Repair needed)
# Repair AP SDD_AP7936 (Repair needed)
# Repair AP SDD_AP7938 (Repair needed)
# Repair AP SDD_AP7940 (Repair needed)
# Repair AP SDD_AP7941 (Repair needed)
# Repair AP SDD_AP7942 (Repair needed)
# Repair AP SDD_AP7943 (Repair needed)
# Repair AP SDD_AP7944 (Repair needed)
# Repair AP SDD_AP7945 (Repair needed)
# Repair AP SDD_AP7946 (Repair needed)
# Repair AP SDD_AP7948 (Repair needed)
# Repair AP SDD_AP7949 (Repair needed)
# Repair AP SDD_AP7951 (Repair needed)
# Repair AP SDD_AP7952 (Repair needed)
# Repair AP SDD_AP7953 (Repair needed)
# Repair AP SDD_AP7955 (Repair needed)
# Repair AP SDD_AP7956 (Repair needed)
# Repair AP SDD_AP7957 (Repair needed)
# Repair AP SDD_AP7959 (Repair needed)
# Repair AP SDD_AP7960 (Repair needed)
# Repair AP SDD_AP7961 (Repair needed)
# Repair AP SDD_AP7962 (Repair needed)
# Repair AP SDD_AP7963 (Repair needed)
# Repair AP SDD_AP7964 (Repair needed)
# Repair AP SDD_AP7965 (Repair needed)
# Repair AP SDD_AP7966 (Repair needed)
# Repair AP SDD_AP7975 (Repair needed)
# Repair AP SDD_AP7976 (Repair needed)
# Repair AP SDD_AP7977 (Repair needed)
# Repair AP SDD_AP7978 (Repair needed)
# Repair AP SDD_AP7980 (Repair needed)
# Repair AP SDD_AP7981 (Repair needed)
# Repair AP SDD_AP7982 (Repair needed)
# Repair AP SDD_AP7983 (Repair needed)
# Repair AP SDD_AP7984 (Repair needed)
# Repair AP SDD_AP7985 (Repair needed)
# Repair AP SDD_AP7986 (Repair needed)
# Repair AP SDD_AP7987 (Repair needed)
# Repair AP SDD_AP7988 (Repair needed)
# Repair AP SDD_AP7990 (Repair needed)
# Repair AP SDD_AP7991 (Repair needed)
# Repair AP SDD_AP7992 (Repair needed)
# Repair AP SDD_AP7993 (Repair needed)
# Repair AP SDD_AP7994 (Repair needed)
# Repair AP SDD_AP7996 (Repair needed)
# Repair AP SDD_AP7997 (Repair needed)
# Repair AP SDD_AP7998 (Repair needed)
# Repair AP SDD_AP8583 (Repair needed)
# Repair AP SDD_AP8584 (Repair needed)
# Repair AP SDD_AP8585 (Repair needed)
# Repair AP SDD_AP8586 (Repair needed)
# Repair AP SDD_AP8587 (Repair needed)
# Repair AP SDD_AP8588 (Repair needed)
# Repair AP SDD_AP8589 (Repair needed)
# Repair AP SDD_AP8591 (Repair needed)
# Repair AP SDD_AP8592 (Repair needed)
# Repair AP SDD_AP8593 (Repair needed)
# Repair AP SDD_AP8594 (Repair needed)
# Repair AP SDD_AP8595 (Repair needed)
# Repair AP SDD_AP8596 (Repair needed)
# Repair AP SDD_AP8600 (Repair needed)
# Repair AP SDD_AP8602 (Repair needed)
# Repair AP SDD_AP8603 (Repair needed)
# Repair AP SDD_AP8604 (Repair needed)
# Repair AP SDD_AP8605 (Repair needed)
# Repair AP SDD_AP8606 (Repair needed)
# Repair AP SDD_AP8607 (Repair needed)
# Repair AP SDD_AP8608 (Repair needed)
# Repair AP SDD_AP8609 (Repair needed)
# Repair AP SDD_AP8610 (Repair needed)
# Repair AP SDD_AP8611 (Repair needed)
# Repair AP SDD_AP8612 (Repair needed)
# Repair AP SDD_AP8613 (Repair needed)
# Repair AP SDD_AP8616 (Repair needed)
# Repair AP SDD_AP8618 (Repair needed)
# Repair AP SDD_AP8619 (Repair needed)
# Repair AP SDD_AP8621 (Repair needed)
# Repair AP SDD_AP8622 (Repair needed)
# Repair AP SDD_AP8624 (Repair needed)
# Repair AP SDD_AP8625 (Repair needed)
# Repair AP SDD_AP8627 (Repair needed)
# Repair AP SDD_AP8631 (Repair needed)
# Repair AP SDD_AP8632 (Repair needed)
# Repair AP SDD_AP8634 (Repair needed)
# Repair AP SLDM_AP6759 (Repair needed)
# Repair AP SMO_AP5812 (Repair needed)
# Repair AP SMO_AP6358 (Repair needed)
# Repair AP SMO_AP6359 (Repair needed)
# Repair AP SMO_AP6360 (Repair needed)
# Repair AP SMO_AP6361 (Repair needed)
# Repair AP SMO_AP6362 (Repair needed)
# Repair AP SMO_AP6363 (Repair needed)
# Repair AP SMO_AP6364 (Repair needed)
# Repair AP SMO_AP6365 (Repair needed)
# Repair AP SMO_AP6366 (Repair needed)
# Repair AP SMO_AP6367 (Repair needed)
# Repair AP SMO_AP6368 (Repair needed)
# Repair AP SMO_AP6369 (Repair needed)
# Repair AP SMO_AP6370 (Repair needed)
# Repair AP SMO_AP6371 (Repair needed)
# Repair AP SMO_AP6372 (Repair needed)
# Repair AP SMO_AP6373 (Repair needed)
# Repair AP SMO_AP6374 (Repair needed)
# Repair AP SMO_AP6375 (Repair needed)
# Repair AP SMO_AP6376 (Repair needed)
# Repair AP SMO_AP6377 (Repair needed)
# Repair AP SOC_AP0008 (Repair needed)
# Repair AP SOC_AP0009 (Repair needed)
# Repair AP SOC_AP0016 (Repair needed)
# Repair AP SOC_AP0019 (Repair needed)
# Repair AP SOC_AP5484 (Repair needed)
# Repair AP SOC_AP5486 (Repair needed)
# Repair AP SWC_AP8392 (Repair needed)
# Repair AP TLIC_AP8335 (Repair needed)
# Repair AP TLIC_AP8341 (Repair needed)
# Repair AP UNIS_AP4024 (Repair needed)
# Repair AP UNIS_AP4050 (Repair needed)
# Repair AP UNIS_AP4051 (Repair needed)
# Repair AP UNIS_AP4052 (Repair needed)
# Repair AP UNIS_AP4055 (Repair needed)
# Repair AP UNIS_AP4056 (Repair needed)
# Repair AP UNIS_AP4058 (Repair needed)
# Repair AP UNIS_AP4059 (Repair needed)
# Repair AP VET_AP2047 (Repair needed)
# Repair AP VET_AP5563 (Repair needed)
# Repair AP VET_AP7824 (Repair needed)

# %%
# แสดงผลลัพธ์ที่แยกตาม Location1
print("Results of AP Repair and Replacement by Location:")
for loc in df["Location1"].unique():
    print(f"\nLocation: {loc}")
    loc_df = df[df["Location1"] == loc]  # กรองเฉพาะข้อมูลในแต่ละ Location

    for i in loc_df.index:
        if repair[i].varValue == 1:
            print(f"  Repair AP {loc_df.loc[i, 'APID']} (Repair needed)")
        if replace[i].varValue == 1:
            print(f"  Replace AP {loc_df.loc[i, 'APID']} (Replacement needed)")
# Out:
# Results of AP Repair and Replacement by Location:
#
# Location: หอสี่สิบปี
#   Repair AP 40YD_AP8534 (Repair needed)
#   Repair AP 40YD_AP8535 (Repair needed)
#   Repair AP 40YD_AP8536 (Repair needed)
#   Repair AP 40YD_AP8537 (Repair needed)
#   Repair AP 40YD_AP8538 (Repair needed)
#   Repair AP 40YD_AP8539 (Repair needed)
#   Repair AP 40YD_AP8540 (Repair needed)
#   Repair AP 40YD_AP8541 (Repair needed)
#   Repair AP 40YD_AP8542 (Repair needed)
#   Repair AP 40YD_AP8543 (Repair needed)
#   Repair AP 40YD_AP8544 (Repair needed)
#   Repair AP 40YD_AP8545 (Repair needed)
#   Repair AP 40YD_AP8546 (Repair needed)
#   Repair AP 40YD_AP8547 (Repair needed)
#   Repair AP 40YD_AP8548 (Repair needed)
#   Repair AP 40YD_AP8549 (Repair needed)
#   Repair AP 40YD_AP8550 (Repair needed)
#   Repair AP 40YD_AP8551 (Repair needed)
#   Repair AP 40YD_AP8552 (Repair needed)
#   Repair AP 40YD_AP8553 (Repair needed)
#   Repair AP 40YD_AP8554 (Repair needed)
#   Repair AP 40YD_AP8555 (Repair needed)
#   Repair AP 40YD_AP8556 (Repair needed)
#   Repair AP 40YD_AP8557 (Repair needed)
#   Repair AP 40YD_AP8559 (Repair needed)
#   Repair AP 40YD_AP8560 (Repair needed)
#   Repair AP 40YD_AP8561 (Repair needed)
#   Repair AP 40YD_AP8562 (Repair needed)
#   Repair AP 40YD_AP8563 (Repair needed)
#   Repair AP 40YD_AP8564 (Repair needed)
#   Repair AP 40YD_AP8565 (Repair needed)
#   Repair AP 40YD_AP8566 (Repair needed)
#   Repair AP 40YD_AP8567 (Repair needed)
#   Repair AP 40YD_AP8568 (Repair needed)
#   Repair AP 40YD_AP8569 (Repair needed)
#   Repair AP 40YD_AP8570 (Repair needed)
#   Repair AP 40YD_AP8571 (Repair needed)
#   Repair AP 40YD_AP8572 (Repair needed)
#   Repair AP 40YD_AP8573 (Repair needed)
#   Repair AP 40YD_AP8574 (Repair needed)
#   Repair AP 40YD_AP8575 (Repair needed)
#   Repair AP 40YD_AP8576 (Repair needed)
#   Repair AP 40YD_AP8577 (Repair needed)
#   Repair AP 40YD_AP8578 (Repair needed)
#   Repair AP 40YD_AP8579 (Repair needed)
#   Repair AP 40YD_AP8580 (Repair needed)
#   Repair AP 40YD_AP8581 (Repair needed)
#   Repair AP 40YD_AP8582 (Repair needed)
#   Repair AP 40YD_AP8637 (Repair needed)
#   Repair AP 40YD_AP8638 (Repair needed)
#   Repair AP 40YD_AP8639 (Repair needed)
#   Repair AP 40YD_AP8640 (Repair needed)
#   Repair AP 40YD_AP8641 (Repair needed)
#   Repair AP 40YD_AP8642 (Repair needed)
#   Repair AP 40YD_AP8643 (Repair needed)
#   Repair AP 40YD_AP8644 (Repair needed)
#   Repair AP 40YD_AP8646 (Repair needed)
#   Repair AP 40YD_AP8647 (Repair needed)
#   Repair AP 40YD_AP8648 (Repair needed)
#   Repair AP 40YD_AP8649 (Repair needed)
#   Repair AP 40YD_AP8650 (Repair needed)
#   Repair AP 40YD_AP8651 (Repair needed)
#   Repair AP 40YD_AP8652 (Repair needed)
#   Repair AP 40YD_AP8653 (Repair needed)
#   Repair AP 40YD_AP8654 (Repair needed)
#   Repair AP 40YD_AP8655 (Repair needed)
#   Repair AP 40YD_AP8656 (Repair needed)
#   Repair AP 40YD_AP8657 (Repair needed)
#   Repair AP 40YD_AP8658 (Repair needed)
#   Repair AP 40YD_AP8659 (Repair needed)
#   Repair AP 40YD_AP8661 (Repair needed)
#   Repair AP 40YD_AP8662 (Repair needed)
#   Repair AP 40YD_AP8663 (Repair needed)
#   Repair AP 40YD_AP8664 (Repair needed)
#   Repair AP 40YD_AP8665 (Repair needed)
#   Repair AP 40YD_AP8666 (Repair needed)
#   Repair AP 40YD_AP8667 (Repair needed)
#   Repair AP 40YD_AP8668 (Repair needed)
#   Repair AP 40YD_AP8669 (Repair needed)
#   Repair AP 40YD_AP8670 (Repair needed)
#   Repair AP 40YD_AP8671 (Repair needed)
#   Repair AP 40YD_AP8672 (Repair needed)
#   Repair AP 40YD_AP8673 (Repair needed)
#   Repair AP 40YD_AP8674 (Repair needed)
#   Repair AP 40YD_AP8676 (Repair needed)
#   Repair AP 40YD_AP8677 (Repair needed)
#   Repair AP 40YD_AP8678 (Repair needed)
#   Repair AP 40YD_AP8679 (Repair needed)
#   Repair AP 40YD_AP8680 (Repair needed)
#   Repair AP 40YD_AP8681 (Repair needed)
#   Repair AP 40YD_AP8682 (Repair needed)
#   Repair AP 40YD_AP8683 (Repair needed)
#   Repair AP 40YD_AP8684 (Repair needed)
#   Repair AP 40YD_AP8685 (Repair needed)
#   Repair AP 40YD_AP8686 (Repair needed)
#   Repair AP 40YD_AP8687 (Repair needed)
#   Repair AP 40YD_AP8688 (Repair needed)
#   Repair AP 40YD_AP8689 (Repair needed)
#   Repair AP 40YD_AP8691 (Repair needed)
#   Repair AP 40YD_AP8692 (Repair needed)
#   Repair AP 40YD_AP8693 (Repair needed)
#   Repair AP 40YD_AP8694 (Repair needed)
#   Repair AP 40YD_AP8695 (Repair needed)
#   Repair AP 40YD_AP8696 (Repair needed)
#   Repair AP 40YD_AP8697 (Repair needed)
#   Repair AP 40YD_AP8698 (Repair needed)
#   Repair AP 40YD_AP8699 (Repair needed)
#   Repair AP 40YD_AP8700 (Repair needed)
#   Repair AP 40YD_AP8701 (Repair needed)
#   Repair AP 40YD_AP8702 (Repair needed)
#   Repair AP 40YD_AP8703 (Repair needed)
#   Repair AP 40YD_AP8704 (Repair needed)
#   Repair AP 40YD_AP8706 (Repair needed)
#   Repair AP 40YD_AP8707 (Repair needed)
#   Repair AP 40YD_AP8708 (Repair needed)
#   Repair AP 40YD_AP8709 (Repair needed)
#   Repair AP 40YD_AP8710 (Repair needed)
#   Repair AP 40YD_AP8711 (Repair needed)
#   Repair AP 40YD_AP8712 (Repair needed)
#   Repair AP 40YD_AP8713 (Repair needed)
#   Repair AP 40YD_AP8714 (Repair needed)
#   Repair AP 40YD_AP8715 (Repair needed)
#   Repair AP 40YD_AP8716 (Repair needed)
#   Repair AP 40YD_AP8717 (Repair needed)
#   Repair AP 40YD_AP8718 (Repair needed)
#   Repair AP 40YD_AP8719 (Repair needed)
#   Repair AP 40YD_AP8721 (Repair needed)
#   Repair AP 40YD_AP8722 (Repair needed)
#   Repair AP 40YD_AP8723 (Repair needed)
#   Repair AP 40YD_AP8724 (Repair needed)
#   Repair AP 40YD_AP8725 (Repair needed)
#   Repair AP 40YD_AP8726 (Repair needed)
#   Repair AP 40YD_AP8727 (Repair needed)
#   Repair AP 40YD_AP8728 (Repair needed)
#   Repair AP 40YD_AP8729 (Repair needed)
#   Repair AP 40YD_AP8730 (Repair needed)
#   Repair AP 40YD_AP8731 (Repair needed)
#   Repair AP 40YD_AP8732 (Repair needed)
#   Repair AP 40YD_AP8733 (Repair needed)
#   Repair AP 40YD_AP8734 (Repair needed)
#   Repair AP 40YD_AP8736 (Repair needed)
#   Repair AP 40YD_AP8737 (Repair needed)
#   Repair AP 40YD_AP8738 (Repair needed)
#   Repair AP 40YD_AP8739 (Repair needed)
#   Repair AP 40YD_AP8740 (Repair needed)
#   Repair AP 40YD_AP8741 (Repair needed)
#   Repair AP 40YD_AP8742 (Repair needed)
#   Repair AP 40YD_AP8743 (Repair needed)
#   Repair AP 40YD_AP8744 (Repair needed)
#   Repair AP 40YD_AP8745 (Repair needed)
#   Repair AP 40YD_AP8746 (Repair needed)
#   Repair AP 40YD_AP8747 (Repair needed)
#   Repair AP 40YD_AP8748 (Repair needed)
#   Repair AP 40YD_AP8749 (Repair needed)
#   Repair AP 40YD_AP8752 (Repair needed)
#   Repair AP 40YD_AP8753 (Repair needed)
#   Repair AP 40YD_AP8754 (Repair needed)
#   Repair AP 40YD_AP8755 (Repair needed)
#   Repair AP 40YD_AP8756 (Repair needed)
#   Repair AP 40YD_AP8757 (Repair needed)
#   Repair AP 40YD_AP8758 (Repair needed)
#   Repair AP 40YD_AP8759 (Repair needed)
#   Repair AP 40YD_AP8760 (Repair needed)
#   Repair AP 40YD_AP8761 (Repair needed)
#   Repair AP 40YD_AP8762 (Repair needed)
#   Repair AP 40YD_AP8763 (Repair needed)
#   Repair AP 40YD_AP8764 (Repair needed)
#   Repair AP 40YD_AP8765 (Repair needed)
#   Repair AP 40YD_AP8767 (Repair needed)
#   Repair AP 40YD_AP8768 (Repair needed)
#   Repair AP 40YD_AP8769 (Repair needed)
#   Repair AP 40YD_AP8770 (Repair needed)
#   Repair AP 40YD_AP8771 (Repair needed)
#   Repair AP 40YD_AP8772 (Repair needed)
#   Repair AP 40YD_AP8773 (Repair needed)
#   Repair AP 40YD_AP8774 (Repair needed)
#   Repair AP 40YD_AP8775 (Repair needed)
#   Repair AP 40YD_AP8776 (Repair needed)
#   Repair AP 40YD_AP8777 (Repair needed)
#   Repair AP 40YD_AP8778 (Repair needed)
#   Repair AP 40YD_AP8779 (Repair needed)
#   Repair AP 40YD_AP8780 (Repair needed)
#   Repair AP 40YD_AP8782 (Repair needed)
#   Repair AP 40YD_AP8783 (Repair needed)
#   Repair AP 40YD_AP8784 (Repair needed)
#   Repair AP 40YD_AP8785 (Repair needed)
#   Repair AP 40YD_AP8786 (Repair needed)
#   Repair AP 40YD_AP8787 (Repair needed)
#   Repair AP 40YD_AP8788 (Repair needed)
#   Repair AP 40YD_AP8789 (Repair needed)
#   Repair AP 40YD_AP8790 (Repair needed)
#   Repair AP 40YD_AP8791 (Repair needed)
#   Repair AP 40YD_AP8792 (Repair needed)
#   Repair AP 40YD_AP8793 (Repair needed)
#   Repair AP 40YD_AP8794 (Repair needed)
#   Repair AP 40YD_AP8795 (Repair needed)
#
# Location: คณะเกษตรศาสตร์
#   Repair AP AGRI_AP1100 (Repair needed)
#
# Location: แม่เหียะ คณะเกษตรศาสตร์
#   Repair AP AGRI_AP8089 (Repair needed)
#   Repair AP AGRI_AP8096 (Repair needed)
#   Repair AP AGRI_AP8098 (Repair needed)
#
# Location: แม่เหียะ คณะเกษตรศาสตร์ วิทยาศาสตร์และเทคโนโลยีอาหาร
#   Repair AP AGRO_AP0308 (Repair needed)
#   Repair AP AGRO_AP5553 (Repair needed)
#
# Location: nan
#
# Location: สนามยิงธนู
#   Repair AP ARCHER_AP6134 (Repair needed)
#
# Location: CAMT
#   Repair AP CAMT_AP0060 (Repair needed)
#   Repair AP CAMT_AP0659 (Repair needed)
#   Repair AP CAMT_AP0662 (Repair needed)
#   Repair AP CAMT_AP0674 (Repair needed)
#   Repair AP CAMT_AP8247 (Repair needed)
#   Repair AP CAMT_AP8250 (Repair needed)
#   Repair AP CAMT_AP8252 (Repair needed)
#   Repair AP CAMT_AP8262 (Repair needed)
#
# Location:  TLIC
#   Repair AP CAMT_AP8251 (Repair needed)
#   Repair AP CAMT_AP8255 (Repair needed)
#   Repair AP CAMT_AP8257 (Repair needed)
#
# Location: อาคารเฉลิมพระเกียรติ์ 7 รอบ
#   Repair AP CELEBRATE_AP6386 (Repair needed)
#
# Location: AIS Playgroud
#   Repair AP CMUHEART_AP6384 (Repair needed)
#
# Location: ITSC สถิติ
#   Repair AP CNOC_AP5710 (Repair needed)
#
# Location: CMU Café and More
#   Repair AP COFFAK_AP6405 (Repair needed)
#
# Location: หน้า อมช
#   Repair AP CONTAINER_AP6408 (Repair needed)
#
# Location: หอพัก คณะทันตแพทย์
#   Repair AP DENTDORM_AP1763 (Repair needed)
#   Repair AP DENTDORM_AP4308 (Repair needed)
#   Repair AP DENTDORM_AP4310 (Repair needed)
#
# Location: คณะทันตแพทย์
#   Repair AP DENT_AP0248 (Repair needed)
#
# Location: คณะศึกษาศาสตร์
#   Repair AP EDU_AP4721 (Repair needed)
#   Repair AP EDU_AP4725 (Repair needed)
#   Repair AP EDU_AP8013 (Repair needed)
#   Repair AP EDU_AP8014 (Repair needed)
#   Repair AP EDU_AP8015 (Repair needed)
#
# Location: คณะวิศวะฯ
#   Repair AP ENG_AP0856 (Repair needed)
#   Repair AP ENG_AP0869 (Repair needed)
#   Repair AP ENG_AP4464 (Repair needed)
#   Repair AP ENG_AP4465 (Repair needed)
#   Repair AP ENG_AP4612 (Repair needed)
#   Repair AP ENG_AP4676 (Repair needed)
#   Repair AP ENG_AP4679 (Repair needed)
#   Repair AP ENG_AP4680 (Repair needed)
#   Repair AP ENG_AP4699 (Repair needed)
#   Repair AP ENG_AP6677 (Repair needed)
#
# Location: แม่เหียะ Energy Research and Development Institute of Nakornping
#   Repair AP ERDI_AP2077 (Repair needed)
#
# Location: แฟลต6
#   Repair AP FLAT6_AP8636 (Repair needed)
#
# Location: MIdS CMU
#   Repair AP GRAD_AP1156 (Repair needed)
#   Repair AP GRAD_AP1159 (Repair needed)
#   Repair AP GRAD_AP1164 (Repair needed)
#   Repair AP GRAD_AP1165 (Repair needed)
#   Repair AP GRAD_AP5293 (Repair needed)
#   Repair AP GRAD_AP5297 (Repair needed)
#   Repair AP GRAD_AP5298 (Repair needed)
#   Repair AP GRAD_AP5299 (Repair needed)
#
# Location: คณะมนุษยศาสตร์
#   Repair AP HM_AP4831 (Repair needed)
#
# Location: ลำพูน HPB4
#   Repair AP HPB4_AP7627 (Repair needed)
#   Repair AP HPB4_AP7630 (Repair needed)
#
# Location: ITSC คอม
#   Repair AP ITSC_AP5687 (Repair needed)
#   Repair AP ITSC_AP5703 (Repair needed)
#   Repair AP ITSC_AP5705 (Repair needed)
#   Repair AP ITSC_AP5706 (Repair needed)
#   Repair AP ITSC_AP5707 (Repair needed)
#   Repair AP ITSC_AP5708 (Repair needed)
#   Repair AP ITSC_AP6229 (Repair needed)
#
# Location: หอสมุด
#   Repair AP LIBR_AP6690 (Repair needed)
#   Repair AP LIBR_AP6691 (Repair needed)
#
# Location: สถาบันภาษา
#   Repair AP LI_AP5309 (Repair needed)
#
# Location: หอพักนักศึกษาแพทย์ชาย 2
#   Repair AP MEDSDORMM2_AP0240 (Repair needed)
#   Repair AP MEDSDORMM2_AP1579 (Repair needed)
#   Repair AP MEDSDORMM2_AP1588 (Repair needed)
#   Repair AP MEDSDORMM2_AP3958 (Repair needed)
#
# Location: คณะแพทยศาสตร์
#   Repair AP MED_AP1198 (Repair needed)
#   Repair AP MED_AP1224 (Repair needed)
#   Repair AP MED_AP1628 (Repair needed)
#   Repair AP MED_AP3185 (Repair needed)
#   Repair AP MED_AP3204 (Repair needed)
#   Repair AP MED_AP3220 (Repair needed)
#   Repair AP MED_AP3221 (Repair needed)
#   Repair AP MED_AP3222 (Repair needed)
#   Repair AP MED_AP3223 (Repair needed)
#   Repair AP MED_AP3224 (Repair needed)
#   Repair AP MED_AP3225 (Repair needed)
#   Repair AP MED_AP3226 (Repair needed)
#   Repair AP MED_AP3228 (Repair needed)
#   Repair AP MED_AP3229 (Repair needed)
#   Repair AP MED_AP3231 (Repair needed)
#   Repair AP MED_AP3233 (Repair needed)
#   Repair AP MED_AP3351 (Repair needed)
#   Repair AP MED_AP3352 (Repair needed)
#   Repair AP MED_AP3353 (Repair needed)
#   Repair AP MED_AP3354 (Repair needed)
#   Repair AP MED_AP3355 (Repair needed)
#   Repair AP MED_AP3360 (Repair needed)
#   Repair AP MED_AP3361 (Repair needed)
#   Repair AP MED_AP3376 (Repair needed)
#   Repair AP MED_AP3384 (Repair needed)
#   Repair AP MED_AP3385 (Repair needed)
#   Repair AP MED_AP3477 (Repair needed)
#   Repair AP MED_AP3700 (Repair needed)
#   Repair AP MED_AP3812 (Repair needed)
#   Repair AP MED_AP6126 (Repair needed)
#   Repair AP MED_AP6582 (Repair needed)
#   Repair AP MED_AP6771 (Repair needed)
#   Repair AP MED_AP6772 (Repair needed)
#
# Location: แม่เหียะ หอพักในกำกับ 3
#   Repair AP MHD_AP22095 (Repair needed)
#   Repair AP MHD_AP6318 (Repair needed)
#   Repair AP MHD_AP6319 (Repair needed)
#
# Location: หอพักนักศึกษาพยาบาล 9
#   Repair AP NURD9_AP1661 (Repair needed)
#
# Location: สนามรักบี้
#   Repair AP OD_AP1010 (Repair needed)
#   Repair AP OD_AP1011 (Repair needed)
#
# Location: หอสมุดคณะวิศวะ
#   Repair AP OD_AP1020 (Repair needed)
#
# Location: สนามฟุตบอลสวนดอกปาร์ค
#   Repair AP OD_AP1027 (Repair needed)
#
# Location: CMU Education Centre
#   Repair AP OFFICE_AP7625 (Repair needed)
#
# Location: SCMC
#   Repair AP OOP_AP6275 (Repair needed)
#
# Location: ทะเบียนวัดผล
#   Repair AP REG_AP5813 (Repair needed)
#
# Location: สถาบันวิจัยวิทยาศาสตร์สุขภาพ
#   Repair AP RIHES_AP1976 (Repair needed)
#   Repair AP RIHES_AP1977 (Repair needed)
#   Repair AP RIHES_AP5727 (Repair needed)
#   Repair AP RIHES_AP5729 (Repair needed)
#   Repair AP RIHES_AP5731 (Repair needed)
#
# Location: สำนักวิชาการวิจับวิทยาศาสตร์
#   Repair AP RIHES_AP1175 (Repair needed)
#
# Location: คณะวิทยาสาสตร์ คอม
#   Repair AP SCI_AP0535 (Repair needed)
#   Repair AP SCI_AP0588 (Repair needed)
#   Repair AP SCI_AP0589 (Repair needed)
#   Repair AP SCI_AP5140 (Repair needed)
#
# Location: หอพักในกำกับสวนดอก
#   Repair AP SDD_AP7901 (Repair needed)
#   Repair AP SDD_AP7902 (Repair needed)
#   Repair AP SDD_AP7907 (Repair needed)
#   Repair AP SDD_AP7908 (Repair needed)
#   Repair AP SDD_AP7909 (Repair needed)
#   Repair AP SDD_AP7910 (Repair needed)
#   Repair AP SDD_AP7912 (Repair needed)
#   Repair AP SDD_AP7913 (Repair needed)
#   Repair AP SDD_AP7914 (Repair needed)
#   Repair AP SDD_AP7915 (Repair needed)
#   Repair AP SDD_AP7917 (Repair needed)
#   Repair AP SDD_AP7918 (Repair needed)
#   Repair AP SDD_AP7919 (Repair needed)
#   Repair AP SDD_AP7920 (Repair needed)
#   Repair AP SDD_AP7921 (Repair needed)
#   Repair AP SDD_AP7922 (Repair needed)
#   Repair AP SDD_AP7923 (Repair needed)
#   Repair AP SDD_AP7924 (Repair needed)
#   Repair AP SDD_AP7926 (Repair needed)
#   Repair AP SDD_AP7927 (Repair needed)
#   Repair AP SDD_AP7928 (Repair needed)
#   Repair AP SDD_AP7930 (Repair needed)
#   Repair AP SDD_AP7931 (Repair needed)
#   Repair AP SDD_AP7932 (Repair needed)
#   Repair AP SDD_AP7935 (Repair needed)
#   Repair AP SDD_AP7936 (Repair needed)
#   Repair AP SDD_AP7938 (Repair needed)
#   Repair AP SDD_AP7940 (Repair needed)
#   Repair AP SDD_AP7941 (Repair needed)
#   Repair AP SDD_AP7942 (Repair needed)
#   Repair AP SDD_AP7943 (Repair needed)
#   Repair AP SDD_AP7944 (Repair needed)
#   Repair AP SDD_AP7945 (Repair needed)
#   Repair AP SDD_AP7946 (Repair needed)
#   Repair AP SDD_AP7948 (Repair needed)
#   Repair AP SDD_AP7949 (Repair needed)
#   Repair AP SDD_AP7951 (Repair needed)
#   Repair AP SDD_AP7952 (Repair needed)
#   Repair AP SDD_AP7953 (Repair needed)
#   Repair AP SDD_AP7955 (Repair needed)
#   Repair AP SDD_AP7956 (Repair needed)
#   Repair AP SDD_AP7957 (Repair needed)
#   Repair AP SDD_AP7959 (Repair needed)
#   Repair AP SDD_AP7960 (Repair needed)
#   Repair AP SDD_AP7961 (Repair needed)
#   Repair AP SDD_AP7962 (Repair needed)
#   Repair AP SDD_AP7963 (Repair needed)
#   Repair AP SDD_AP7964 (Repair needed)
#   Repair AP SDD_AP7965 (Repair needed)
#   Repair AP SDD_AP7966 (Repair needed)
#   Repair AP SDD_AP7975 (Repair needed)
#   Repair AP SDD_AP7976 (Repair needed)
#   Repair AP SDD_AP7977 (Repair needed)
#   Repair AP SDD_AP7978 (Repair needed)
#   Repair AP SDD_AP7980 (Repair needed)
#   Repair AP SDD_AP7981 (Repair needed)
#   Repair AP SDD_AP7982 (Repair needed)
#   Repair AP SDD_AP7983 (Repair needed)
#   Repair AP SDD_AP7984 (Repair needed)
#   Repair AP SDD_AP7985 (Repair needed)
#   Repair AP SDD_AP7986 (Repair needed)
#   Repair AP SDD_AP7987 (Repair needed)
#   Repair AP SDD_AP7988 (Repair needed)
#   Repair AP SDD_AP7990 (Repair needed)
#   Repair AP SDD_AP7991 (Repair needed)
#   Repair AP SDD_AP7992 (Repair needed)
#   Repair AP SDD_AP7993 (Repair needed)
#   Repair AP SDD_AP7994 (Repair needed)
#   Repair AP SDD_AP7996 (Repair needed)
#   Repair AP SDD_AP7997 (Repair needed)
#   Repair AP SDD_AP7998 (Repair needed)
#   Repair AP SDD_AP8583 (Repair needed)
#   Repair AP SDD_AP8584 (Repair needed)
#   Repair AP SDD_AP8585 (Repair needed)
#   Repair AP SDD_AP8586 (Repair needed)
#   Repair AP SDD_AP8587 (Repair needed)
#   Repair AP SDD_AP8588 (Repair needed)
#   Repair AP SDD_AP8589 (Repair needed)
#   Repair AP SDD_AP8591 (Repair needed)
#   Repair AP SDD_AP8592 (Repair needed)
#   Repair AP SDD_AP8593 (Repair needed)
#   Repair AP SDD_AP8594 (Repair needed)
#   Repair AP SDD_AP8595 (Repair needed)
#   Repair AP SDD_AP8596 (Repair needed)
#   Repair AP SDD_AP8600 (Repair needed)
#   Repair AP SDD_AP8602 (Repair needed)
#   Repair AP SDD_AP8603 (Repair needed)
#   Repair AP SDD_AP8604 (Repair needed)
#   Repair AP SDD_AP8605 (Repair needed)
#   Repair AP SDD_AP8606 (Repair needed)
#   Repair AP SDD_AP8607 (Repair needed)
#   Repair AP SDD_AP8608 (Repair needed)
#   Repair AP SDD_AP8609 (Repair needed)
#   Repair AP SDD_AP8610 (Repair needed)
#   Repair AP SDD_AP8611 (Repair needed)
#   Repair AP SDD_AP8612 (Repair needed)
#   Repair AP SDD_AP8613 (Repair needed)
#   Repair AP SDD_AP8616 (Repair needed)
#   Repair AP SDD_AP8618 (Repair needed)
#   Repair AP SDD_AP8619 (Repair needed)
#   Repair AP SDD_AP8621 (Repair needed)
#   Repair AP SDD_AP8622 (Repair needed)
#   Repair AP SDD_AP8624 (Repair needed)
#   Repair AP SDD_AP8625 (Repair needed)
#   Repair AP SDD_AP8627 (Repair needed)
#   Repair AP SDD_AP8631 (Repair needed)
#   Repair AP SDD_AP8632 (Repair needed)
#   Repair AP SDD_AP8634 (Repair needed)
#
# Location: ศาลาธรรม
#   Repair AP SLDM_AP6759 (Repair needed)
#
# Location: อมชเก่า
#   Repair AP SMO_AP5812 (Repair needed)
#   Repair AP SMO_AP6358 (Repair needed)
#   Repair AP SMO_AP6359 (Repair needed)
#   Repair AP SMO_AP6360 (Repair needed)
#   Repair AP SMO_AP6361 (Repair needed)
#   Repair AP SMO_AP6362 (Repair needed)
#   Repair AP SMO_AP6363 (Repair needed)
#   Repair AP SMO_AP6364 (Repair needed)
#   Repair AP SMO_AP6365 (Repair needed)
#   Repair AP SMO_AP6366 (Repair needed)
#   Repair AP SMO_AP6367 (Repair needed)
#   Repair AP SMO_AP6368 (Repair needed)
#   Repair AP SMO_AP6369 (Repair needed)
#   Repair AP SMO_AP6370 (Repair needed)
#   Repair AP SMO_AP6371 (Repair needed)
#   Repair AP SMO_AP6372 (Repair needed)
#   Repair AP SMO_AP6373 (Repair needed)
#   Repair AP SMO_AP6374 (Repair needed)
#   Repair AP SMO_AP6375 (Repair needed)
#   Repair AP SMO_AP6376 (Repair needed)
#   Repair AP SMO_AP6377 (Repair needed)
#
# Location: คณะสังคมศาสตร์
#   Repair AP SOC_AP0008 (Repair needed)
#   Repair AP SOC_AP0009 (Repair needed)
#   Repair AP SOC_AP0016 (Repair needed)
#   Repair AP SOC_AP0019 (Repair needed)
#   Repair AP SOC_AP5484 (Repair needed)
#   Repair AP SOC_AP5486 (Repair needed)
#
# Location: ศูนย์ส่งเสริมพฤตพลังผู้สูงอายุ
#   Repair AP SWC_AP8392 (Repair needed)
#
# Location: TLIC
#   Repair AP TLIC_AP8335 (Repair needed)
#   Repair AP TLIC_AP8341 (Repair needed)
#
# Location: หอพักนักศึกษา ICDI
#   Repair AP UNIS_AP4024 (Repair needed)
#   Repair AP UNIS_AP4050 (Repair needed)
#   Repair AP UNIS_AP4051 (Repair needed)
#   Repair AP UNIS_AP4052 (Repair needed)
#   Repair AP UNIS_AP4055 (Repair needed)
#   Repair AP UNIS_AP4056 (Repair needed)
#   Repair AP UNIS_AP4058 (Repair needed)
#   Repair AP UNIS_AP4059 (Repair needed)
#
# Location: แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง
#   Repair AP VET_AP2047 (Repair needed)
#   Repair AP VET_AP5563 (Repair needed)
#   Repair AP VET_AP7824 (Repair needed)

# %%
# แสดงผลลัพธ์ที่แยกตาม Location1 พร้อมนับจำนวน
print("Results of AP Repair and Replacement by Location:")

for loc in df["Location1"].unique():
    print(f"\nLocation: {loc}")
    loc_df = df[df["Location1"] == loc]  # กรองเฉพาะข้อมูลในแต่ละ Location

    # ตัวแปรนับจำนวนการซ่อมและการเปลี่ยนแปลง
    repair_count = 0
    replace_count = 0

    for i in loc_df.index:
        if repair[i].varValue == 1:
            print(f"  Repair AP {loc_df.loc[i, 'APID']} (Repair needed)")
            repair_count += 1
        if replace[i].varValue == 1:
            print(f"  Replace AP {loc_df.loc[i, 'APID']} (Replacement needed)")
            replace_count += 1

    # แสดงจำนวนการซ่อมและการเปลี่ยนแปลงในแต่ละ Location
    print(f"  Total Repairs in {loc}: {repair_count}")
    print(f"  Total Replacements in {loc}: {replace_count}")
# Out:
# Results of AP Repair and Replacement by Location:
#
# Location: หอสี่สิบปี
#   Repair AP 40YD_AP8534 (Repair needed)
#   Repair AP 40YD_AP8535 (Repair needed)
#   Repair AP 40YD_AP8536 (Repair needed)
#   Repair AP 40YD_AP8537 (Repair needed)
#   Repair AP 40YD_AP8538 (Repair needed)
#   Repair AP 40YD_AP8539 (Repair needed)
#   Repair AP 40YD_AP8540 (Repair needed)
#   Repair AP 40YD_AP8541 (Repair needed)
#   Repair AP 40YD_AP8542 (Repair needed)
#   Repair AP 40YD_AP8543 (Repair needed)
#   Repair AP 40YD_AP8544 (Repair needed)
#   Repair AP 40YD_AP8545 (Repair needed)
#   Repair AP 40YD_AP8546 (Repair needed)
#   Repair AP 40YD_AP8547 (Repair needed)
#   Repair AP 40YD_AP8548 (Repair needed)
#   Repair AP 40YD_AP8549 (Repair needed)
#   Repair AP 40YD_AP8550 (Repair needed)
#   Repair AP 40YD_AP8551 (Repair needed)
#   Repair AP 40YD_AP8552 (Repair needed)
#   Repair AP 40YD_AP8553 (Repair needed)
#   Repair AP 40YD_AP8554 (Repair needed)
#   Repair AP 40YD_AP8555 (Repair needed)
#   Repair AP 40YD_AP8556 (Repair needed)
#   Repair AP 40YD_AP8557 (Repair needed)
#   Repair AP 40YD_AP8559 (Repair needed)
#   Repair AP 40YD_AP8560 (Repair needed)
#   Repair AP 40YD_AP8561 (Repair needed)
#   Repair AP 40YD_AP8562 (Repair needed)
#   Repair AP 40YD_AP8563 (Repair needed)
#   Repair AP 40YD_AP8564 (Repair needed)
#   Repair AP 40YD_AP8565 (Repair needed)
#   Repair AP 40YD_AP8566 (Repair needed)
#   Repair AP 40YD_AP8567 (Repair needed)
#   Repair AP 40YD_AP8568 (Repair needed)
#   Repair AP 40YD_AP8569 (Repair needed)
#   Repair AP 40YD_AP8570 (Repair needed)
#   Repair AP 40YD_AP8571 (Repair needed)
#   Repair AP 40YD_AP8572 (Repair needed)
#   Repair AP 40YD_AP8573 (Repair needed)
#   Repair AP 40YD_AP8574 (Repair needed)
#   Repair AP 40YD_AP8575 (Repair needed)
#   Repair AP 40YD_AP8576 (Repair needed)
#   Repair AP 40YD_AP8577 (Repair needed)
#   Repair AP 40YD_AP8578 (Repair needed)
#   Repair AP 40YD_AP8579 (Repair needed)
#   Repair AP 40YD_AP8580 (Repair needed)
#   Repair AP 40YD_AP8581 (Repair needed)
#   Repair AP 40YD_AP8582 (Repair needed)
#   Repair AP 40YD_AP8637 (Repair needed)
#   Repair AP 40YD_AP8638 (Repair needed)
#   Repair AP 40YD_AP8639 (Repair needed)
#   Repair AP 40YD_AP8640 (Repair needed)
#   Repair AP 40YD_AP8641 (Repair needed)
#   Repair AP 40YD_AP8642 (Repair needed)
#   Repair AP 40YD_AP8643 (Repair needed)
#   Repair AP 40YD_AP8644 (Repair needed)
#   Repair AP 40YD_AP8646 (Repair needed)
#   Repair AP 40YD_AP8647 (Repair needed)
#   Repair AP 40YD_AP8648 (Repair needed)
#   Repair AP 40YD_AP8649 (Repair needed)
#   Repair AP 40YD_AP8650 (Repair needed)
#   Repair AP 40YD_AP8651 (Repair needed)
#   Repair AP 40YD_AP8652 (Repair needed)
#   Repair AP 40YD_AP8653 (Repair needed)
#   Repair AP 40YD_AP8654 (Repair needed)
#   Repair AP 40YD_AP8655 (Repair needed)
#   Repair AP 40YD_AP8656 (Repair needed)
#   Repair AP 40YD_AP8657 (Repair needed)
#   Repair AP 40YD_AP8658 (Repair needed)
#   Repair AP 40YD_AP8659 (Repair needed)
#   Repair AP 40YD_AP8661 (Repair needed)
#   Repair AP 40YD_AP8662 (Repair needed)
#   Repair AP 40YD_AP8663 (Repair needed)
#   Repair AP 40YD_AP8664 (Repair needed)
#   Repair AP 40YD_AP8665 (Repair needed)
#   Repair AP 40YD_AP8666 (Repair needed)
#   Repair AP 40YD_AP8667 (Repair needed)
#   Repair AP 40YD_AP8668 (Repair needed)
#   Repair AP 40YD_AP8669 (Repair needed)
#   Repair AP 40YD_AP8670 (Repair needed)
#   Repair AP 40YD_AP8671 (Repair needed)
#   Repair AP 40YD_AP8672 (Repair needed)
#   Repair AP 40YD_AP8673 (Repair needed)
#   Repair AP 40YD_AP8674 (Repair needed)
#   Repair AP 40YD_AP8676 (Repair needed)
#   Repair AP 40YD_AP8677 (Repair needed)
#   Repair AP 40YD_AP8678 (Repair needed)
#   Repair AP 40YD_AP8679 (Repair needed)
#   Repair AP 40YD_AP8680 (Repair needed)
#   Repair AP 40YD_AP8681 (Repair needed)
#   Repair AP 40YD_AP8682 (Repair needed)
#   Repair AP 40YD_AP8683 (Repair needed)
#   Repair AP 40YD_AP8684 (Repair needed)
#   Repair AP 40YD_AP8685 (Repair needed)
#   Repair AP 40YD_AP8686 (Repair needed)
#   Repair AP 40YD_AP8687 (Repair needed)
#   Repair AP 40YD_AP8688 (Repair needed)
#   Repair AP 40YD_AP8689 (Repair needed)
#   Repair AP 40YD_AP8691 (Repair needed)
#   Repair AP 40YD_AP8692 (Repair needed)
#   Repair AP 40YD_AP8693 (Repair needed)
#   Repair AP 40YD_AP8694 (Repair needed)
#   Repair AP 40YD_AP8695 (Repair needed)
#   Repair AP 40YD_AP8696 (Repair needed)
#   Repair AP 40YD_AP8697 (Repair needed)
#   Repair AP 40YD_AP8698 (Repair needed)
#   Repair AP 40YD_AP8699 (Repair needed)
#   Repair AP 40YD_AP8700 (Repair needed)
#   Repair AP 40YD_AP8701 (Repair needed)
#   Repair AP 40YD_AP8702 (Repair needed)
#   Repair AP 40YD_AP8703 (Repair needed)
#   Repair AP 40YD_AP8704 (Repair needed)
#   Repair AP 40YD_AP8706 (Repair needed)
#   Repair AP 40YD_AP8707 (Repair needed)
#   Repair AP 40YD_AP8708 (Repair needed)
#   Repair AP 40YD_AP8709 (Repair needed)
#   Repair AP 40YD_AP8710 (Repair needed)
#   Repair AP 40YD_AP8711 (Repair needed)
#   Repair AP 40YD_AP8712 (Repair needed)
#   Repair AP 40YD_AP8713 (Repair needed)
#   Repair AP 40YD_AP8714 (Repair needed)
#   Repair AP 40YD_AP8715 (Repair needed)
#   Repair AP 40YD_AP8716 (Repair needed)
#   Repair AP 40YD_AP8717 (Repair needed)
#   Repair AP 40YD_AP8718 (Repair needed)
#   Repair AP 40YD_AP8719 (Repair needed)
#   Repair AP 40YD_AP8721 (Repair needed)
#   Repair AP 40YD_AP8722 (Repair needed)
#   Repair AP 40YD_AP8723 (Repair needed)
#   Repair AP 40YD_AP8724 (Repair needed)
#   Repair AP 40YD_AP8725 (Repair needed)
#   Repair AP 40YD_AP8726 (Repair needed)
#   Repair AP 40YD_AP8727 (Repair needed)
#   Repair AP 40YD_AP8728 (Repair needed)
#   Repair AP 40YD_AP8729 (Repair needed)
#   Repair AP 40YD_AP8730 (Repair needed)
#   Repair AP 40YD_AP8731 (Repair needed)
#   Repair AP 40YD_AP8732 (Repair needed)
#   Repair AP 40YD_AP8733 (Repair needed)
#   Repair AP 40YD_AP8734 (Repair needed)
#   Repair AP 40YD_AP8736 (Repair needed)
#   Repair AP 40YD_AP8737 (Repair needed)
#   Repair AP 40YD_AP8738 (Repair needed)
#   Repair AP 40YD_AP8739 (Repair needed)
#   Repair AP 40YD_AP8740 (Repair needed)
#   Repair AP 40YD_AP8741 (Repair needed)
#   Repair AP 40YD_AP8742 (Repair needed)
#   Repair AP 40YD_AP8743 (Repair needed)
#   Repair AP 40YD_AP8744 (Repair needed)
#   Repair AP 40YD_AP8745 (Repair needed)
#   Repair AP 40YD_AP8746 (Repair needed)
#   Repair AP 40YD_AP8747 (Repair needed)
#   Repair AP 40YD_AP8748 (Repair needed)
#   Repair AP 40YD_AP8749 (Repair needed)
#   Repair AP 40YD_AP8752 (Repair needed)
#   Repair AP 40YD_AP8753 (Repair needed)
#   Repair AP 40YD_AP8754 (Repair needed)
#   Repair AP 40YD_AP8755 (Repair needed)
#   Repair AP 40YD_AP8756 (Repair needed)
#   Repair AP 40YD_AP8757 (Repair needed)
#   Repair AP 40YD_AP8758 (Repair needed)
#   Repair AP 40YD_AP8759 (Repair needed)
#   Repair AP 40YD_AP8760 (Repair needed)
#   Repair AP 40YD_AP8761 (Repair needed)
#   Repair AP 40YD_AP8762 (Repair needed)
#   Repair AP 40YD_AP8763 (Repair needed)
#   Repair AP 40YD_AP8764 (Repair needed)
#   Repair AP 40YD_AP8765 (Repair needed)
#   Repair AP 40YD_AP8767 (Repair needed)
#   Repair AP 40YD_AP8768 (Repair needed)
#   Repair AP 40YD_AP8769 (Repair needed)
#   Repair AP 40YD_AP8770 (Repair needed)
#   Repair AP 40YD_AP8771 (Repair needed)
#   Repair AP 40YD_AP8772 (Repair needed)
#   Repair AP 40YD_AP8773 (Repair needed)
#   Repair AP 40YD_AP8774 (Repair needed)
#   Repair AP 40YD_AP8775 (Repair needed)
#   Repair AP 40YD_AP8776 (Repair needed)
#   Repair AP 40YD_AP8777 (Repair needed)
#   Repair AP 40YD_AP8778 (Repair needed)
#   Repair AP 40YD_AP8779 (Repair needed)
#   Repair AP 40YD_AP8780 (Repair needed)
#   Repair AP 40YD_AP8782 (Repair needed)
#   Repair AP 40YD_AP8783 (Repair needed)
#   Repair AP 40YD_AP8784 (Repair needed)
#   Repair AP 40YD_AP8785 (Repair needed)
#   Repair AP 40YD_AP8786 (Repair needed)
#   Repair AP 40YD_AP8787 (Repair needed)
#   Repair AP 40YD_AP8788 (Repair needed)
#   Repair AP 40YD_AP8789 (Repair needed)
#   Repair AP 40YD_AP8790 (Repair needed)
#   Repair AP 40YD_AP8791 (Repair needed)
#   Repair AP 40YD_AP8792 (Repair needed)
#   Repair AP 40YD_AP8793 (Repair needed)
#   Repair AP 40YD_AP8794 (Repair needed)
#   Repair AP 40YD_AP8795 (Repair needed)
#   Total Repairs in หอสี่สิบปี: 196
#   Total Replacements in หอสี่สิบปี: 0
#
# Location: คณะเกษตรศาสตร์
#   Repair AP AGRI_AP1100 (Repair needed)
#   Total Repairs in คณะเกษตรศาสตร์: 1
#   Total Replacements in คณะเกษตรศาสตร์: 0
#
# Location: แม่เหียะ คณะเกษตรศาสตร์
#   Repair AP AGRI_AP8089 (Repair needed)
#   Repair AP AGRI_AP8096 (Repair needed)
#   Repair AP AGRI_AP8098 (Repair needed)
#   Total Repairs in แม่เหียะ คณะเกษตรศาสตร์: 3
#   Total Replacements in แม่เหียะ คณะเกษตรศาสตร์: 0
#
# Location: แม่เหียะ คณะเกษตรศาสตร์ วิทยาศาสตร์และเทคโนโลยีอาหาร
#   Repair AP AGRO_AP0308 (Repair needed)
#   Repair AP AGRO_AP5553 (Repair needed)
#   Total Repairs in แม่เหียะ คณะเกษตรศาสตร์ วิทยาศาสตร์และเทคโนโลยีอาหาร: 2
#   Total Replacements in แม่เหียะ คณะเกษตรศาสตร์ วิทยาศาสตร์และเทคโนโลยีอาหาร: 0
#
# Location: nan
#   Total Repairs in nan: 0
#   Total Replacements in nan: 0
#
# Location: สนามยิงธนู
#   Repair AP ARCHER_AP6134 (Repair needed)
#   Total Repairs in สนามยิงธนู: 1
#   Total Replacements in สนามยิงธนู: 0
#
# Location: CAMT
#   Repair AP CAMT_AP0060 (Repair needed)
#   Repair AP CAMT_AP0659 (Repair needed)
#   Repair AP CAMT_AP0662 (Repair needed)
#   Repair AP CAMT_AP0674 (Repair needed)
#   Repair AP CAMT_AP8247 (Repair needed)
#   Repair AP CAMT_AP8250 (Repair needed)
#   Repair AP CAMT_AP8252 (Repair needed)
#   Repair AP CAMT_AP8262 (Repair needed)
#   Total Repairs in CAMT: 8
#   Total Replacements in CAMT: 0
#
# Location:  TLIC
#   Repair AP CAMT_AP8251 (Repair needed)
#   Repair AP CAMT_AP8255 (Repair needed)
#   Repair AP CAMT_AP8257 (Repair needed)
#   Total Repairs in  TLIC: 3
#   Total Replacements in  TLIC: 0
#
# Location: อาคารเฉลิมพระเกียรติ์ 7 รอบ
#   Repair AP CELEBRATE_AP6386 (Repair needed)
#   Total Repairs in อาคารเฉลิมพระเกียรติ์ 7 รอบ: 1
#   Total Replacements in อาคารเฉลิมพระเกียรติ์ 7 รอบ: 0
#
# Location: AIS Playgroud
#   Repair AP CMUHEART_AP6384 (Repair needed)
#   Total Repairs in AIS Playgroud: 1
#   Total Replacements in AIS Playgroud: 0
#
# Location: ITSC สถิติ
#   Repair AP CNOC_AP5710 (Repair needed)
#   Total Repairs in ITSC สถิติ: 1
#   Total Replacements in ITSC สถิติ: 0
#
# Location: CMU Café and More
#   Repair AP COFFAK_AP6405 (Repair needed)
#   Total Repairs in CMU Café and More: 1
#   Total Replacements in CMU Café and More: 0
#
# Location: หน้า อมช
#   Repair AP CONTAINER_AP6408 (Repair needed)
#   Total Repairs in หน้า อมช: 1
#   Total Replacements in หน้า อมช: 0
#
# Location: หอพัก คณะทันตแพทย์
#   Repair AP DENTDORM_AP1763 (Repair needed)
#   Repair AP DENTDORM_AP4308 (Repair needed)
#   Repair AP DENTDORM_AP4310 (Repair needed)
#   Total Repairs in หอพัก คณะทันตแพทย์: 3
#   Total Replacements in หอพัก คณะทันตแพทย์: 0
#
# Location: คณะทันตแพทย์
#   Repair AP DENT_AP0248 (Repair needed)
#   Total Repairs in คณะทันตแพทย์: 1
#   Total Replacements in คณะทันตแพทย์: 0
#
# Location: คณะศึกษาศาสตร์
#   Repair AP EDU_AP4721 (Repair needed)
#   Repair AP EDU_AP4725 (Repair needed)
#   Repair AP EDU_AP8013 (Repair needed)
#   Repair AP EDU_AP8014 (Repair needed)
#   Repair AP EDU_AP8015 (Repair needed)
#   Total Repairs in คณะศึกษาศาสตร์: 5
#   Total Replacements in คณะศึกษาศาสตร์: 0
#
# Location: คณะวิศวะฯ
#   Repair AP ENG_AP0856 (Repair needed)
#   Repair AP ENG_AP0869 (Repair needed)
#   Repair AP ENG_AP4464 (Repair needed)
#   Repair AP ENG_AP4465 (Repair needed)
#   Repair AP ENG_AP4612 (Repair needed)
#   Repair AP ENG_AP4676 (Repair needed)
#   Repair AP ENG_AP4679 (Repair needed)
#   Repair AP ENG_AP4680 (Repair needed)
#   Repair AP ENG_AP4699 (Repair needed)
#   Repair AP ENG_AP6677 (Repair needed)
#   Total Repairs in คณะวิศวะฯ: 10
#   Total Replacements in คณะวิศวะฯ: 0
#
# Location: แม่เหียะ Energy Research and Development Institute of Nakornping
#   Repair AP ERDI_AP2077 (Repair needed)
#   Total Repairs in แม่เหียะ Energy Research and Development Institute of Nakornping: 1
#   Total Replacements in แม่เหียะ Energy Research and Development Institute of Nakornping: 0
#
# Location: แฟลต6
#   Repair AP FLAT6_AP8636 (Repair needed)
#   Total Repairs in แฟลต6: 1
#   Total Replacements in แฟลต6: 0
#
# Location: MIdS CMU
#   Repair AP GRAD_AP1156 (Repair needed)
#   Repair AP GRAD_AP1159 (Repair needed)
#   Repair AP GRAD_AP1164 (Repair needed)
#   Repair AP GRAD_AP1165 (Repair needed)
#   Repair AP GRAD_AP5293 (Repair needed)
#   Repair AP GRAD_AP5297 (Repair needed)
#   Repair AP GRAD_AP5298 (Repair needed)
#   Repair AP GRAD_AP5299 (Repair needed)
#   Total Repairs in MIdS CMU: 8
#   Total Replacements in MIdS CMU: 0
#
# Location: คณะมนุษยศาสตร์
#   Repair AP HM_AP4831 (Repair needed)
#   Total Repairs in คณะมนุษยศาสตร์: 1
#   Total Replacements in คณะมนุษยศาสตร์: 0
#
# Location: ลำพูน HPB4
#   Repair AP HPB4_AP7627 (Repair needed)
#   Repair AP HPB4_AP7630 (Repair needed)
#   Total Repairs in ลำพูน HPB4: 2
#   Total Replacements in ลำพูน HPB4: 0
#
# Location: ITSC คอม
#   Repair AP ITSC_AP5687 (Repair needed)
#   Repair AP ITSC_AP5703 (Repair needed)
#   Repair AP ITSC_AP5705 (Repair needed)
#   Repair AP ITSC_AP5706 (Repair needed)
#   Repair AP ITSC_AP5707 (Repair needed)
#   Repair AP ITSC_AP5708 (Repair needed)
#   Repair AP ITSC_AP6229 (Repair needed)
#   Total Repairs in ITSC คอม: 7
#   Total Replacements in ITSC คอม: 0
#
# Location: หอสมุด
#   Repair AP LIBR_AP6690 (Repair needed)
#   Repair AP LIBR_AP6691 (Repair needed)
#   Total Repairs in หอสมุด: 2
#   Total Replacements in หอสมุด: 0
#
# Location: สถาบันภาษา
#   Repair AP LI_AP5309 (Repair needed)
#   Total Repairs in สถาบันภาษา: 1
#   Total Replacements in สถาบันภาษา: 0
#
# Location: หอพักนักศึกษาแพทย์ชาย 2
#   Repair AP MEDSDORMM2_AP0240 (Repair needed)
#   Repair AP MEDSDORMM2_AP1579 (Repair needed)
#   Repair AP MEDSDORMM2_AP1588 (Repair needed)
#   Repair AP MEDSDORMM2_AP3958 (Repair needed)
#   Total Repairs in หอพักนักศึกษาแพทย์ชาย 2: 4
#   Total Replacements in หอพักนักศึกษาแพทย์ชาย 2: 0
#
# Location: คณะแพทยศาสตร์
#   Repair AP MED_AP1198 (Repair needed)
#   Repair AP MED_AP1224 (Repair needed)
#   Repair AP MED_AP1628 (Repair needed)
#   Repair AP MED_AP3185 (Repair needed)
#   Repair AP MED_AP3204 (Repair needed)
#   Repair AP MED_AP3220 (Repair needed)
#   Repair AP MED_AP3221 (Repair needed)
#   Repair AP MED_AP3222 (Repair needed)
#   Repair AP MED_AP3223 (Repair needed)
#   Repair AP MED_AP3224 (Repair needed)
#   Repair AP MED_AP3225 (Repair needed)
#   Repair AP MED_AP3226 (Repair needed)
#   Repair AP MED_AP3228 (Repair needed)
#   Repair AP MED_AP3229 (Repair needed)
#   Repair AP MED_AP3231 (Repair needed)
#   Repair AP MED_AP3233 (Repair needed)
#   Repair AP MED_AP3351 (Repair needed)
#   Repair AP MED_AP3352 (Repair needed)
#   Repair AP MED_AP3353 (Repair needed)
#   Repair AP MED_AP3354 (Repair needed)
#   Repair AP MED_AP3355 (Repair needed)
#   Repair AP MED_AP3360 (Repair needed)
#   Repair AP MED_AP3361 (Repair needed)
#   Repair AP MED_AP3376 (Repair needed)
#   Repair AP MED_AP3384 (Repair needed)
#   Repair AP MED_AP3385 (Repair needed)
#   Repair AP MED_AP3477 (Repair needed)
#   Repair AP MED_AP3700 (Repair needed)
#   Repair AP MED_AP3812 (Repair needed)
#   Repair AP MED_AP6126 (Repair needed)
#   Repair AP MED_AP6582 (Repair needed)
#   Repair AP MED_AP6771 (Repair needed)
#   Repair AP MED_AP6772 (Repair needed)
#   Total Repairs in คณะแพทยศาสตร์: 33
#   Total Replacements in คณะแพทยศาสตร์: 0
#
# Location: แม่เหียะ หอพักในกำกับ 3
#   Repair AP MHD_AP22095 (Repair needed)
#   Repair AP MHD_AP6318 (Repair needed)
#   Repair AP MHD_AP6319 (Repair needed)
#   Total Repairs in แม่เหียะ หอพักในกำกับ 3: 3
#   Total Replacements in แม่เหียะ หอพักในกำกับ 3: 0
#
# Location: หอพักนักศึกษาพยาบาล 9
#   Repair AP NURD9_AP1661 (Repair needed)
#   Total Repairs in หอพักนักศึกษาพยาบาล 9: 1
#   Total Replacements in หอพักนักศึกษาพยาบาล 9: 0
#
# Location: สนามรักบี้
#   Repair AP OD_AP1010 (Repair needed)
#   Repair AP OD_AP1011 (Repair needed)
#   Total Repairs in สนามรักบี้: 2
#   Total Replacements in สนามรักบี้: 0
#
# Location: หอสมุดคณะวิศวะ
#   Repair AP OD_AP1020 (Repair needed)
#   Total Repairs in หอสมุดคณะวิศวะ: 1
#   Total Replacements in หอสมุดคณะวิศวะ: 0
#
# Location: สนามฟุตบอลสวนดอกปาร์ค
#   Repair AP OD_AP1027 (Repair needed)
#   Total Repairs in สนามฟุตบอลสวนดอกปาร์ค: 1
#   Total Replacements in สนามฟุตบอลสวนดอกปาร์ค: 0
#
# Location: CMU Education Centre
#   Repair AP OFFICE_AP7625 (Repair needed)
#   Total Repairs in CMU Education Centre: 1
#   Total Replacements in CMU Education Centre: 0
#
# Location: SCMC
#   Repair AP OOP_AP6275 (Repair needed)
#   Total Repairs in SCMC: 1
#   Total Replacements in SCMC: 0
#
# Location: ทะเบียนวัดผล
#   Repair AP REG_AP5813 (Repair needed)
#   Total Repairs in ทะเบียนวัดผล: 1
#   Total Replacements in ทะเบียนวัดผล: 0
#
# Location: สถาบันวิจัยวิทยาศาสตร์สุขภาพ
#   Repair AP RIHES_AP1976 (Repair needed)
#   Repair AP RIHES_AP1977 (Repair needed)
#   Repair AP RIHES_AP5727 (Repair needed)
#   Repair AP RIHES_AP5729 (Repair needed)
#   Repair AP RIHES_AP5731 (Repair needed)
#   Total Repairs in สถาบันวิจัยวิทยาศาสตร์สุขภาพ: 5
#   Total Replacements in สถาบันวิจัยวิทยาศาสตร์สุขภาพ: 0
#
# Location: สำนักวิชาการวิจับวิทยาศาสตร์
#   Repair AP RIHES_AP1175 (Repair needed)
#   Total Repairs in สำนักวิชาการวิจับวิทยาศาสตร์: 1
#   Total Replacements in สำนักวิชาการวิจับวิทยาศาสตร์: 0
#
# Location: คณะวิทยาสาสตร์ คอม
#   Repair AP SCI_AP0535 (Repair needed)
#   Repair AP SCI_AP0588 (Repair needed)
#   Repair AP SCI_AP0589 (Repair needed)
#   Repair AP SCI_AP5140 (Repair needed)
#   Total Repairs in คณะวิทยาสาสตร์ คอม: 4
#   Total Replacements in คณะวิทยาสาสตร์ คอม: 0
#
# Location: หอพักในกำกับสวนดอก
#   Repair AP SDD_AP7901 (Repair needed)
#   Repair AP SDD_AP7902 (Repair needed)
#   Repair AP SDD_AP7907 (Repair needed)
#   Repair AP SDD_AP7908 (Repair needed)
#   Repair AP SDD_AP7909 (Repair needed)
#   Repair AP SDD_AP7910 (Repair needed)
#   Repair AP SDD_AP7912 (Repair needed)
#   Repair AP SDD_AP7913 (Repair needed)
#   Repair AP SDD_AP7914 (Repair needed)
#   Repair AP SDD_AP7915 (Repair needed)
#   Repair AP SDD_AP7917 (Repair needed)
#   Repair AP SDD_AP7918 (Repair needed)
#   Repair AP SDD_AP7919 (Repair needed)
#   Repair AP SDD_AP7920 (Repair needed)
#   Repair AP SDD_AP7921 (Repair needed)
#   Repair AP SDD_AP7922 (Repair needed)
#   Repair AP SDD_AP7923 (Repair needed)
#   Repair AP SDD_AP7924 (Repair needed)
#   Repair AP SDD_AP7926 (Repair needed)
#   Repair AP SDD_AP7927 (Repair needed)
#   Repair AP SDD_AP7928 (Repair needed)
#   Repair AP SDD_AP7930 (Repair needed)
#   Repair AP SDD_AP7931 (Repair needed)
#   Repair AP SDD_AP7932 (Repair needed)
#   Repair AP SDD_AP7935 (Repair needed)
#   Repair AP SDD_AP7936 (Repair needed)
#   Repair AP SDD_AP7938 (Repair needed)
#   Repair AP SDD_AP7940 (Repair needed)
#   Repair AP SDD_AP7941 (Repair needed)
#   Repair AP SDD_AP7942 (Repair needed)
#   Repair AP SDD_AP7943 (Repair needed)
#   Repair AP SDD_AP7944 (Repair needed)
#   Repair AP SDD_AP7945 (Repair needed)
#   Repair AP SDD_AP7946 (Repair needed)
#   Repair AP SDD_AP7948 (Repair needed)
#   Repair AP SDD_AP7949 (Repair needed)
#   Repair AP SDD_AP7951 (Repair needed)
#   Repair AP SDD_AP7952 (Repair needed)
#   Repair AP SDD_AP7953 (Repair needed)
#   Repair AP SDD_AP7955 (Repair needed)
#   Repair AP SDD_AP7956 (Repair needed)
#   Repair AP SDD_AP7957 (Repair needed)
#   Repair AP SDD_AP7959 (Repair needed)
#   Repair AP SDD_AP7960 (Repair needed)
#   Repair AP SDD_AP7961 (Repair needed)
#   Repair AP SDD_AP7962 (Repair needed)
#   Repair AP SDD_AP7963 (Repair needed)
#   Repair AP SDD_AP7964 (Repair needed)
#   Repair AP SDD_AP7965 (Repair needed)
#   Repair AP SDD_AP7966 (Repair needed)
#   Repair AP SDD_AP7975 (Repair needed)
#   Repair AP SDD_AP7976 (Repair needed)
#   Repair AP SDD_AP7977 (Repair needed)
#   Repair AP SDD_AP7978 (Repair needed)
#   Repair AP SDD_AP7980 (Repair needed)
#   Repair AP SDD_AP7981 (Repair needed)
#   Repair AP SDD_AP7982 (Repair needed)
#   Repair AP SDD_AP7983 (Repair needed)
#   Repair AP SDD_AP7984 (Repair needed)
#   Repair AP SDD_AP7985 (Repair needed)
#   Repair AP SDD_AP7986 (Repair needed)
#   Repair AP SDD_AP7987 (Repair needed)
#   Repair AP SDD_AP7988 (Repair needed)
#   Repair AP SDD_AP7990 (Repair needed)
#   Repair AP SDD_AP7991 (Repair needed)
#   Repair AP SDD_AP7992 (Repair needed)
#   Repair AP SDD_AP7993 (Repair needed)
#   Repair AP SDD_AP7994 (Repair needed)
#   Repair AP SDD_AP7996 (Repair needed)
#   Repair AP SDD_AP7997 (Repair needed)
#   Repair AP SDD_AP7998 (Repair needed)
#   Repair AP SDD_AP8583 (Repair needed)
#   Repair AP SDD_AP8584 (Repair needed)
#   Repair AP SDD_AP8585 (Repair needed)
#   Repair AP SDD_AP8586 (Repair needed)
#   Repair AP SDD_AP8587 (Repair needed)
#   Repair AP SDD_AP8588 (Repair needed)
#   Repair AP SDD_AP8589 (Repair needed)
#   Repair AP SDD_AP8591 (Repair needed)
#   Repair AP SDD_AP8592 (Repair needed)
#   Repair AP SDD_AP8593 (Repair needed)
#   Repair AP SDD_AP8594 (Repair needed)
#   Repair AP SDD_AP8595 (Repair needed)
#   Repair AP SDD_AP8596 (Repair needed)
#   Repair AP SDD_AP8600 (Repair needed)
#   Repair AP SDD_AP8602 (Repair needed)
#   Repair AP SDD_AP8603 (Repair needed)
#   Repair AP SDD_AP8604 (Repair needed)
#   Repair AP SDD_AP8605 (Repair needed)
#   Repair AP SDD_AP8606 (Repair needed)
#   Repair AP SDD_AP8607 (Repair needed)
#   Repair AP SDD_AP8608 (Repair needed)
#   Repair AP SDD_AP8609 (Repair needed)
#   Repair AP SDD_AP8610 (Repair needed)
#   Repair AP SDD_AP8611 (Repair needed)
#   Repair AP SDD_AP8612 (Repair needed)
#   Repair AP SDD_AP8613 (Repair needed)
#   Repair AP SDD_AP8616 (Repair needed)
#   Repair AP SDD_AP8618 (Repair needed)
#   Repair AP SDD_AP8619 (Repair needed)
#   Repair AP SDD_AP8621 (Repair needed)
#   Repair AP SDD_AP8622 (Repair needed)
#   Repair AP SDD_AP8624 (Repair needed)
#   Repair AP SDD_AP8625 (Repair needed)
#   Repair AP SDD_AP8627 (Repair needed)
#   Repair AP SDD_AP8631 (Repair needed)
#   Repair AP SDD_AP8632 (Repair needed)
#   Repair AP SDD_AP8634 (Repair needed)
#   Total Repairs in หอพักในกำกับสวนดอก: 108
#   Total Replacements in หอพักในกำกับสวนดอก: 0
#
# Location: ศาลาธรรม
#   Repair AP SLDM_AP6759 (Repair needed)
#   Total Repairs in ศาลาธรรม: 1
#   Total Replacements in ศาลาธรรม: 0
#
# Location: อมชเก่า
#   Repair AP SMO_AP5812 (Repair needed)
#   Repair AP SMO_AP6358 (Repair needed)
#   Repair AP SMO_AP6359 (Repair needed)
#   Repair AP SMO_AP6360 (Repair needed)
#   Repair AP SMO_AP6361 (Repair needed)
#   Repair AP SMO_AP6362 (Repair needed)
#   Repair AP SMO_AP6363 (Repair needed)
#   Repair AP SMO_AP6364 (Repair needed)
#   Repair AP SMO_AP6365 (Repair needed)
#   Repair AP SMO_AP6366 (Repair needed)
#   Repair AP SMO_AP6367 (Repair needed)
#   Repair AP SMO_AP6368 (Repair needed)
#   Repair AP SMO_AP6369 (Repair needed)
#   Repair AP SMO_AP6370 (Repair needed)
#   Repair AP SMO_AP6371 (Repair needed)
#   Repair AP SMO_AP6372 (Repair needed)
#   Repair AP SMO_AP6373 (Repair needed)
#   Repair AP SMO_AP6374 (Repair needed)
#   Repair AP SMO_AP6375 (Repair needed)
#   Repair AP SMO_AP6376 (Repair needed)
#   Repair AP SMO_AP6377 (Repair needed)
#   Total Repairs in อมชเก่า: 21
#   Total Replacements in อมชเก่า: 0
#
# Location: คณะสังคมศาสตร์
#   Repair AP SOC_AP0008 (Repair needed)
#   Repair AP SOC_AP0009 (Repair needed)
#   Repair AP SOC_AP0016 (Repair needed)
#   Repair AP SOC_AP0019 (Repair needed)
#   Repair AP SOC_AP5484 (Repair needed)
#   Repair AP SOC_AP5486 (Repair needed)
#   Total Repairs in คณะสังคมศาสตร์: 6
#   Total Replacements in คณะสังคมศาสตร์: 0
#
# Location: ศูนย์ส่งเสริมพฤตพลังผู้สูงอายุ
#   Repair AP SWC_AP8392 (Repair needed)
#   Total Repairs in ศูนย์ส่งเสริมพฤตพลังผู้สูงอายุ: 1
#   Total Replacements in ศูนย์ส่งเสริมพฤตพลังผู้สูงอายุ: 0
#
# Location: TLIC
#   Repair AP TLIC_AP8335 (Repair needed)
#   Repair AP TLIC_AP8341 (Repair needed)
#   Total Repairs in TLIC: 2
#   Total Replacements in TLIC: 0
#
# Location: หอพักนักศึกษา ICDI
#   Repair AP UNIS_AP4024 (Repair needed)
#   Repair AP UNIS_AP4050 (Repair needed)
#   Repair AP UNIS_AP4051 (Repair needed)
#   Repair AP UNIS_AP4052 (Repair needed)
#   Repair AP UNIS_AP4055 (Repair needed)
#   Repair AP UNIS_AP4056 (Repair needed)
#   Repair AP UNIS_AP4058 (Repair needed)
#   Repair AP UNIS_AP4059 (Repair needed)
#   Total Repairs in หอพักนักศึกษา ICDI: 8
#   Total Replacements in หอพักนักศึกษา ICDI: 0
#
# Location: แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง
#   Repair AP VET_AP2047 (Repair needed)
#   Repair AP VET_AP5563 (Repair needed)
#   Repair AP VET_AP7824 (Repair needed)
#   Total Repairs in แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง: 3
#   Total Replacements in แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง: 0

# %%
# แสดงผลลัพธ์
df["Optimal_Repair"] = [repair[i].varValue for i in df.index]
df["Optimal_Replace"] = [replace[i].varValue for i in df.index]
# Out:
# <ipython-input-32-3e740c6d1929>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Optimal_Repair"] = [repair[i].varValue for i in df.index]
# <ipython-input-32-3e740c6d1929>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Optimal_Replace"] = [replace[i].varValue for i in df.index]

# %%
# คำนวณต้นทุนรวม
total_cost = sum(
    df.loc[i, "Maintenance Cost"] * df.loc[i, "Optimal_Repair"] +
    ap_types[df.loc[i, "ap_type"]]["install_cost"] * df.loc[i, "Optimal_Replace"]
    for i in df.index
)

# %%
print("Optimal Solution Found!")
print("Total Cost:", total_cost)
# Out:
# Optimal Solution Found!
# Total Cost: 554500.0

# %%
# # แสดงต้นทุนในแต่ละ Location
# print("Cost Breakdown by Location:")
# for loc in df["Location1"].unique():
#     loc_df = df[df["Location1"] == loc]  # กรองข้อมูลตาม Location1

#     # คำนวณต้นทุนสำหรับ Location นี้
#     loc_cost = sum(
#         loc_df.loc[i, "Maintenance Cost"] * loc_df.loc[i, "Optimal_Repair"] +
#         ap_types[loc_df.loc[i, "ap_type"]]["install_cost"] * loc_df.loc[i, "Optimal_Replace"]
#         for i in loc_df.index
#     )

#     print(f"\nLocation: {loc}")
#     print(f"  Total Cost for {loc}: {loc_cost}")
# Out:
# Cost Breakdown by Location:

# %%
# สร้าง DataFrame สำหรับแสดงต้นทุนในแต่ละ Location
cost_by_location = []

for loc in df["Location1"].unique():
    loc_df = df[df["Location1"] == loc]  # กรองข้อมูลตาม Location1

    # คำนวณต้นทุนสำหรับ Location นี้
    loc_cost = sum(
        loc_df.loc[i, "Maintenance Cost"] * loc_df.loc[i, "Optimal_Repair"] +
        ap_types[loc_df.loc[i, "ap_type"]]["install_cost"] * loc_df.loc[i, "Optimal_Replace"]
        for i in loc_df.index
    )

    # เก็บข้อมูลใน list
    cost_by_location.append({"Location": loc, "Total Cost": loc_cost})

# สร้าง DataFrame จาก list ที่เก็บข้อมูลต้นทุน
cost_df = pd.DataFrame(cost_by_location)

# แสดง DataFrame ที่ได้
cost_df
# Out:
#                                              Location  Total Cost
# 0                                          หอสี่สิบปี    196000.0
# 1                                      คณะเกษตรศาสตร์      1000.0
# 2                             แม่เหียะ คณะเกษตรศาสตร์      3000.0
# 3   แม่เหียะ คณะเกษตรศาสตร์ วิทยาศาสตร์และเทคโนโลย...      2000.0
# 4                                                 NaN         0.0
# 5                                          สนามยิงธนู      1000.0
# 6                                                CAMT     12000.0
# 7                                                TLIC      3000.0
# 8                         อาคารเฉลิมพระเกียรติ์ 7 รอบ      1000.0
# 9                                       AIS Playgroud      1000.0
# 10                                         ITSC สถิติ      1000.0
# 11                                  CMU Café and More      1000.0
# 12                                           หน้า อมช      1000.0
# 13                                 หอพัก คณะทันตแพทย์      4500.0
# 14                                       คณะทันตแพทย์      1500.0
# 15                                     คณะศึกษาศาสตร์      5000.0
# 16                                          คณะวิศวะฯ     10000.0
# 17  แม่เหียะ Energy Research and Development Insti...      1000.0
# 18                                              แฟลต6      1000.0
# 19                                           MIdS CMU      8000.0
# 20                                     คณะมนุษยศาสตร์       500.0
# 21                                         ลำพูน HPB4      2000.0
# 22                                           ITSC คอม      7000.0
# 23                                             หอสมุด      1000.0
# 24                                         สถาบันภาษา      1000.0
# 25                            หอพักนักศึกษาแพทย์ชาย 2      6000.0
# 26                                      คณะแพทยศาสตร์     49500.0
# 27                            แม่เหียะ หอพักในกำกับ 3      3000.0
# 28                              หอพักนักศึกษาพยาบาล 9      1500.0
# 29                                         สนามรักบี้      2000.0
# 30                                     หอสมุดคณะวิศวะ      1000.0
# 31                              สนามฟุตบอลสวนดอกปาร์ค      1500.0
# 32                               CMU Education Centre      1000.0
# 33                                               SCMC      1000.0
# 34                                       ทะเบียนวัดผล      1000.0
# 35                       สถาบันวิจัยวิทยาศาสตร์สุขภาพ      7500.0
# 36                       สำนักวิชาการวิจับวิทยาศาสตร์      1000.0
# 37                                 คณะวิทยาสาสตร์ คอม      4000.0
# 38                                 หอพักในกำกับสวนดอก    162000.0
# 39                                           ศาลาธรรม      1000.0
# 40                                            อมชเก่า     21000.0
# 41                                     คณะสังคมศาสตร์      6000.0
# 42                     ศูนย์ส่งเสริมพฤตพลังผู้สูงอายุ      1000.0
# 43                                               TLIC      2000.0
# 44                                 หอพักนักศึกษา ICDI     12000.0
# 45                    แม่เหียะ ศูนย์สุขภาพสัตว์เลี้ยง      3000.0
